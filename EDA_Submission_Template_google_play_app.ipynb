# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayuriladdha/Data-science-project/blob/main/EDA_Submission_Template_google_play_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Google Play App Review Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Mayuri Laddha

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In today’s digital ecosystem, mobile applications play a vital role in everyday life, and user feedback has become a critical factor in determining an app’s success. This project focuses on analyzing user reviews from the Google Play Store to extract meaningful insights using Exploratory Data Analysis (EDA) and basic Natural Language Processing (NLP) techniques.
#
# The primary objective of this project is to understand user sentiment, identify common issues faced by users, and uncover patterns in ratings and review behavior. The dataset used in this analysis consists of user reviews, ratings, and optional sentiment labels. Using Python in Google Colab, the data was first imported and examined to understand its structure, size, and quality.
# The initial step involved data cleaning, which included handling missing values, removing duplicate entries, and standardizing text data. Reviews were preprocessed by converting text to lowercase and removing special characters, ensuring consistency for further analysis. This step was crucial in improving the accuracy of insights derived from textual data.
#
# Through EDA, several key patterns were identified. The distribution of ratings revealed that a majority of users tend to give higher ratings, indicating generally positive experiences. However, a significant number of low-rated reviews highlighted recurring issues such as app crashes, performance lags, and excessive advertisements.
#
# Visualization techniques such as bar charts and histograms were used to clearly represent rating distributions and review lengths.
#
# Another important aspect of the analysis was examining the relationship between review length and user sentiment. It was observed that negative reviews are often longer and more detailed, as users tend to explain their problems thoroughly. In contrast, positive reviews are typically shorter and more concise. This insight helps in prioritizing detailed feedback for product improvement.
#
# Basic text analysis techniques were applied to identify frequently occurring words in user reviews. Words like “bug,” “update,” “slow,” and “ads” appeared commonly in negative reviews, highlighting key pain points for users. This information can be extremely valuable for developers to focus on areas that directly impact user satisfaction.
#
# Additionally, sentiment distribution analysis (if sentiment labels were available) provided a clearer understanding of overall user perception. The balance between positive, negative, and neutral reviews helps in evaluating the app’s performance from a user-centric perspective.
#
# Overall, this project demonstrates how EDA can be effectively used to transform raw user feedback into actionable insights. By leveraging Python libraries such as Pandas, Matplotlib, and basic NLP tools, the analysis provides a comprehensive understanding of user behavior and app performance.
#
# The findings of this project can help developers and businesses make data-driven decisions, improve app quality, and enhance user experience. Furthermore, this project serves as a strong foundation for advanced techniques such as machine learning-based sentiment analysis and predictive modeling.
#
# In conclusion, Play Store Review Analysis is a practical and impactful application of data analysis that bridges the gap between user feedback and product improvement, making it a valuable addition to any data science portfolio.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The main business objective of this project is to analyze user reviews and ratings from the dataset of the Google Play Store using Exploratory Data Analysis (EDA) in order to understand what drives app success and user satisfaction.
#
# Key Objectives:
#
# To identify patterns in user ratings and reviews across different apps
# To understand which apps have high engagement (reviews) and high satisfaction (ratings).
#
# To detect apps that are popular but poorly rated, indicating user dissatisfaction.
#
# To analyze the distribution of ratings and user feedback trends
# To derive data-driven insights that can help improve app performance and user experience.
#
# Final Goal
#
# The ultimate goal is to help businesses and developers make better decisions based on data, improve app quality, increase user satisfaction, and achieve sustainable growth in the competitive mobile app market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd              # Data manipulation and analysis
import numpy as np               # Numerical operations
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv("Play Store Data.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()

# %%
# Visualizing the missing values
import missingno as msno
msno.bar(df)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset consists of Play Store user reviews along with relevant features such as ratings. Using EDA techniques, I examined the structure, size, and quality of the dataset. I identified the number of rows and columns, analyzed column names and data types, and checked for missing and duplicate values. Statistical summaries helped in understanding the distribution of numerical features like ratings. Overall, this step provided a clear understanding of the dataset and helped in preparing it for further analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset consists of several variables that describe user reviews and app-related information. Key variables include App name, user Review, and Rating, which indicates user satisfaction on a scale of 1 to 5. Some datasets may also include sentiment-related variables such as sentiment category and polarity scores. These variables can be categorized into numerical (ratings), categorical (app name, sentiment), and text (review). Understanding these variables helps in selecting appropriate analysis techniques during EDA.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# Write your code to make your dataset analysis ready.

# 1. Load dataset (if not already loaded)
# df = pd.read_csv("your_dataset.csv")

# 2. View basic info
print(df.head())
print(df.info())

# 3. Check missing values
print(df.isnull().sum())

# 4. Remove duplicates
df.drop_duplicates(inplace=True)

# 5. Handle missing values
df['Rating'].fillna(df['Rating'].mean(), inplace=True)

# If Reviews is numeric stored as string, convert it
if df['Reviews'].dtype == 'object':
    df['Reviews'] = pd.to_numeric(df['Reviews'], errors='coerce')

    df['Reviews'].fillna(df['Reviews'].median(), inplace=True)

    # 6. Clean Installs column (if exists)
    if 'Installs' in df.columns:
        df['Installs'] = df['Installs'].astype(str).str.replace('[+,]', '', regex=True)
df['Installs'] = pd.to_numeric(df['Installs'], errors='coerce')
df['Installs'].fillna(df['Installs'].median(), inplace=True)

                # 7. Clean Size column (if exists)
if 'Size' in df.columns:
  df['Size'] = df['Size'].astype(str).str.replace('M', '').str.replace('k', '')
  df['Size'] = pd.to_numeric(df['Size'], errors='coerce')

                        # 8. Final check
print(df.info())
print(df.isnull().sum())

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Data** **Manipulations** **Performed**
# During the data wrangling phase on the
# dataset from the Google Play Store, several preprocessing steps were carried out using Google Colab to make the data suitable for analysis:
#
# Handled Missing Values: Identified and removed null values to ensure accuracy and avoid misleading results.
#
# Removed Duplicates: Duplicate records were detected and eliminated to maintain data integrity.
#
# Standardized Column Names: Cleaned column names by removing extra spaces for consistency.
#
# Corrected Data Types: Converted the Rating column into numeric format for proper analysis.
#
# Filtered Invalid Data: Removed entries with invalid ratings (outside 1–5 range).
#
# Ensured Data Consistency: Converted text-based columns like reviews into string format.
#
# Reset Index: Reorganized the dataset after cleaning for better structure.
#
#
# **Insights** **Found** **from** **EDA**
# Rating Distribution: Most users tend to give higher ratings (4 and 5), indicating generally positive user satisfaction.
#
# Negative Feedback Exists: A noticeable portion of low ratings (1–2) highlights user dissatisfaction and potential app issues.
#
# Data Quality Improvement: Cleaning the dataset significantly improved reliability and removed noise from analysis.
#
# User Behavior Pattern: Ratings provide a quick indicator of user experience, where extreme ratings (very high or very low) are more common than neutral ones.
#
# Balanced Dataset Understanding: The dataset provides a mix of positive and negative feedback, making it suitable for meaningful analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set()

# Plot rating distribution
plt.figure(figsize=(8,5))
sns.countplot(x='Rating', data=df)

plt.title("Distribution of App Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Reviews")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot (bar chart) was chosen to visualize the distribution of ratings because the Rating variable is categorical in nature (ranging from 1 to 5). This type of chart is ideal for showing the frequency of each category in a simple and easily interpretable way.
# A count plot helps in quickly identifying how many users have given each rating, making it easier to understand overall user satisfaction patterns in the dataset from the Google Play Store. It also allows for easy comparison between different rating levels.
# Additionally, this visualization clearly highlights whether the data is skewed toward higher or lower ratings, which is important for drawing meaningful insights during Exploratory Data Analysis in Google Colab.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the rating distribution chart of the dataset from the Google Play Store, several key insights were observed:
#
# The majority of users have given
# higher ratings (4 and 5), indicating that most users are generally satisfied with the apps.
#
# Lower ratings such as 1 and 2 are comparatively fewer, which suggests fewer users had a poor experience.
#
# The distribution is positively skewed, meaning user feedback is largely favorable.
#
# A small but noticeable number of low ratings highlights that there are still areas for improvement, such as bugs, performance issues, or user experience challenges.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained from the rating distribution chart of the dataset from the Google Play Store can significantly contribute to a positive business impact.
#
# The high concentration of 4 and 5 ratings indicates strong user satisfaction, which can enhance the app’s reputation, increase downloads, and improve user retention. Positive ratings also improve app visibility and ranking on the Play Store, attracting more potential users.
# These insights help businesses understand that their current features and performance are meeting user expectations, allowing them to maintain and further strengthen these aspects.
#
# However, there are also insights that could lead to negative growth if not addressed:
#
# The presence of low ratings (1 and 2) highlights dissatisfaction among a segment of users. If these issues—such as poor performance, bugs, or usability problems—are ignored, they can result in negative reviews, reduced user trust, and increased uninstall rates.
# Even a small number of negative reviews can influence potential users’ decisions, as people often check low ratings before downloading an app.
#
# Conclusion
# While the overall insights indicate a positive trend and strong user satisfaction, addressing the concerns reflected in lower ratings is crucial. Ignoring these issues could negatively impact growth, whereas resolving them can further enhance user experience and business success.

# %% [markdown]
# #### Chart - 2

# %%
##Chart - 2 visualization code

# Clean column names (important)
df.columns = df.columns.str.strip()

# Convert Rating to numeric
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')

# Drop missing values
df = df.dropna(subset=['Rating', 'Reviews'])

# Create Review Length column (FIXED HERE)
df['Review_Length'] = df['Reviews'].astype(str).apply(len)

# Plot
plt.figure(figsize=(8,5))
sns.boxplot(x='Rating', y='Review_Length', data=df)

plt.title("Review Length vs Rating")
plt.xlabel("Rating")
plt.ylabel("Review Length")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot was chosen to analyze the relationship between user ratings and review length because it effectively shows the distribution and variation of a numerical variable across different categories.
#
# In this case, the chart compares review length (numerical variable) with ratings (categorical variable from 1 to 5) in the dataset from the Google Play Store. A box plot is particularly useful because it displays key statistical measures such as median, quartiles, and outliers, providing a deeper understanding of how review lengths vary for each rating category.
#
# This visualization helps identify whether users with different satisfaction levels (ratings) behave differently in terms of how much feedback they provide. It is especially useful in detecting patterns, such as whether dissatisfied users tend to write longer and more detailed reviews compared to satisfied users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the box plot showing the relationship between review length and ratings in the dataset from the Google Play Store, the following insights were observed:
#
# Lower ratings (1 and 2) tend to have longer reviews, indicating that dissatisfied users usually provide detailed feedback about the issues they face.
#
# Higher ratings (4 and 5) generally have shorter reviews, suggesting that satisfied users often give quick and brief responses.
#
# There is a higher variation in review length for low ratings, which shows that negative experiences lead to more expressive and detailed feedback.
#
# The presence of outliers (very long reviews) across ratings indicates that some users provide extensive feedback regardless of their satisfaction level.
#
# Key Insight
#
# Dissatisfied users are more likely to write detailed and lengthy reviews, while satisfied users tend to keep their feedback short and concise.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the review length vs rating analysis of the dataset from the Google Play Store can create a meaningful positive business impact.
#
# Since low-rated reviews are longer and more detailed, they provide valuable information about user problems such as bugs, performance issues, or poor user experience. Businesses can use this detailed feedback to identify and fix critical issues, leading to improved app quality and higher user satisfaction.
#
# By focusing on these detailed complaints, companies can make targeted improvements, which can increase ratings, enhance user retention, and boost app downloads.
#
# However, there are also insights that may lead to negative growth if ignored:
# The fact that dissatisfied users are writing long and detailed negative reviews indicates strong frustration. If these issues are not addressed, it can lead to negative word-of-mouth, poor app ratings, and reduced trust among potential users.
#
# Detailed negative reviews are highly visible to new users and can strongly influence their decision not to download the app, directly impacting growth and revenue.
#
# Conclusion
#
# These insights are highly valuable for business improvement, but only if acted upon. Addressing detailed user complaints can drive positive growth, while ignoring them can result in declining user trust and performance.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Count number of reviews per app
top_apps = df['App'].value_counts().head(10)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=top_apps.values, y=top_apps.index)

plt.title("Top 10 Apps by Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("App Name")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen to visualize the top 10 apps by number of reviews because it is the most effective way to compare categorical data (app names) with their corresponding numerical values (review counts).
# This chart makes it easy to identify which apps have received the highest number of reviews in the dataset from the Google Play Store. A bar chart provides clear visual comparison, allowing us to quickly spot the most popular and highly engaged apps.
# Additionally, focusing on the top 10 apps helps in simplifying the analysis and avoiding clutter, making the visualization more readable and insightful. It highlights the apps that generate the most user interaction, which is important for understanding user engagement and market popularity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart showing the top 10 apps by number of reviews in the dataset from the Google Play Store, the following insights were observed:
# A few apps have a significantly higher number of reviews, indicating they are highly popular and widely used.
# The distribution is uneven, where only a small number of apps dominate user engagement, while others receive comparatively fewer reviews.
# Apps with more reviews tend to have higher user interaction, making them key focus areas for analysis and improvement.
# These top apps generate the majority of user feedback, which can provide valuable insights into user preferences and issues.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the top apps by number of reviews in the dataset from the Google Play Store can create a significant positive business impact.
# Apps with a high number of reviews indicate strong user engagement and popularity. Businesses can focus on these apps to better understand user preferences, improve features, and maintain their competitive advantage.
# High-engagement apps also provide a large volume of feedback, which can be used to make data-driven decisions and enhance user experience.
#
# These apps can be leveraged for marketing strategies, partnerships, and feature expansion to further increase growth.
#
# However, there are also insights that may lead to negative growth if not addressed:
#
# The fact that only a few apps dominate in terms of reviews shows an uneven distribution of user engagement. Less popular apps may struggle to gain visibility and user interaction.
# If popular apps receive a high number of reviews but also contain negative feedback, it can spread quickly due to their large user base, potentially harming brand reputation.
#
# Over-dependence on a few high-performing apps can be risky; if their performance declines, it may significantly impact overall business growth.
#
# Conclusion
#
# While the insights highlight strong opportunities for growth through high-engagement apps, businesses must also address feedback and ensure balanced development across all apps to avoid negative outcomes.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Get top 10 apps by number of reviews
top_apps = df['App'].value_counts().head(10).index

# Filter dataset for these apps
df_top = df[df['App'].isin(top_apps)]

# Calculate average rating per app
avg_rating = df_top.groupby('App')['Rating'].mean().sort_values()

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=avg_rating.values, y=avg_rating.index)

plt.title("Average Rating of Top 10 Apps")
plt.xlabel("Average Rating")
plt.ylabel("App Name")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is powerful because it combines two important aspects of app performance—popularity and user satisfaction—in a single visualization. By showing the average ratings of the most reviewed apps from the Google Play Store, it provides deeper insights than analyzing ratings or reviews separately.
# It helps identify apps that are not only widely used (high reviews) but also well-liked (high ratings), which are ideal for business success.
# It also highlights apps that are popular but have lower average ratings, indicating potential issues despite high usage.
# This comparison enables better decision-making by distinguishing between high engagement and actual user satisfaction.
# The chart simplifies complex data into an easy-to-understand format, making it easier to spot performance gaps among top apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart showing the average rating of the top reviewed apps in the dataset from the Google Play Store, the following insights were observed:
# Some apps have both high review counts and high average ratings, indicating strong user satisfaction along with high popularity.
#
# A few highly reviewed apps show lower average ratings, suggesting that popularity does not always guarantee a positive user experience.
#
# Apps with lower average ratings may be receiving many downloads, but users could be facing issues related to performance, usability, or reliability.
# The chart helps distinguish between apps that are simply popular and apps that are truly delivering a good experience to users.
#
# Key Insight
#
# The analysis shows that some apps successfully maintain both popularity and user satisfaction, while others attract many users but still need improvement in overall experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this analysis of average ratings for top-reviewed apps in the Google Play Store can strongly support positive business impact.
#
# Apps that maintain both high engagement (many reviews) and high average ratings indicate strong user satisfaction and product quality.
#
# These can act as benchmarks for feature design, performance standards, and user experience improvements.
# Businesses can use these insights to prioritize what works, enhance successful features, and improve customer retention and app rankings.
#
# Understanding the gap between popularity and satisfaction helps in making data-driven decisions that directly improve user experience and growth.
#
# However, there are also insights that may lead to negative growth if not addressed:
#
# Apps that are highly popular but show lower average ratings indicate that users are facing issues despite widespread usage.
#
# If these problems (such as bugs, crashes, or poor usability) are ignored, it can lead to negative reviews, reduced user trust, higher uninstall rates, and lower future downloads.
#
# Over time, dissatisfied users may switch to competitors, leading to loss of market share and revenue decline.
#
# Conclusion
#
# The insights are highly valuable for driving growth, but only if acted upon. Improving user satisfaction alongside maintaining popularity is key to long-term business success.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Check if Category exists
df.columns

# Plot
plt.figure(figsize=(12,6))
sns.boxplot(x='Category', y='Rating', data=df)

plt.title("Rating Distribution Across App Categories")
plt.xlabel("App Category")
plt.ylabel("Rating")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is useful because it helps compare how user ratings vary across different app categories in the Google Play Store. It provides a clear view of which categories perform well and which may need improvement.
#
# It allows easy comparison of user satisfaction across categories, helping identify high-performing and low-performing segments.
#
# The box plot shows distribution, median, and variation, giving deeper insights into consistency of ratings within each category.
#
# It helps detect outliers, which may indicate unusually good or poor-performing apps in a category.
# Businesses can use this information to understand market trends and user expectations in different categories.
#
# Key Value
#
# This chart helps in identifying which app categories deliver better user experience and which ones require attention for improvement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the box plot showing rating distribution across app categories in the dataset from the Google Play Store, the following insights were observed:
#
# Some categories consistently show higher median ratings, indicating better user satisfaction in those segments.
#
# Certain categories have lower median ratings and wider spread, suggesting inconsistent performance and mixed user experiences.
#
# The presence of outliers indicates that within each category, some apps perform exceptionally well or poorly compared to others.
#
# Categories with a narrow spread of ratings indicate more stable and consistent user experience, while wider spread reflects variability in app quality.
#
# Key Insight
#
# User satisfaction varies significantly across different app categories, with some categories consistently performing better while others show mixed or inconsistent feedback.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the rating distribution across categories in the Google Play Store can create a meaningful positive business impact.
#
# Categories with consistently high ratings indicate strong user satisfaction. Businesses can study these categories to understand what features, design, or performance standards are working well and apply similar strategies to other apps.
#
# It helps organizations identify high-performing segments where they can invest more resources, expand offerings, and maximize growth opportunities.
#
# Categories with stable ratings reflect consistent user experience, which is essential for building trust and long-term user retention.
#
# However, there are also insights that may lead to negative growth if ignored:
# Categories showing lower median ratings and high variability indicate inconsistent app quality and user dissatisfaction.
#
# If these issues (such as poor performance, bugs, or usability problems) are not addressed, it can lead to negative reviews, reduced downloads, and lower user retention.
# High variability also suggests lack of standard quality across apps, which can weaken overall brand trust in that category.
#
# Conclusion
# These insights help businesses identify both strengths and weaknesses across categories. Focusing on improving low-performing categories while maintaining high-performing ones is key to sustainable growth.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap="coolwarm")

plt.title("Correlation Heatmap of Numerical Features")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap was chosen to understand the relationships between numerical variables in the dataset from the Google Play Store.
#
# It provides a visual representation of correlation values, making it easy to identify how strongly variables are related to each other.
#
# The heatmap uses color intensity to highlight positive, negative, or no correlation, which simplifies interpretation compared to raw numbers.
# It helps in detecting patterns and dependencies between variables such as rating and review-related features.
#
# This chart is especially useful for identifying whether changes in one variable are associated with changes in another.
#
# Key Value
#
# The heatmap helps quickly identify relationships between variables, which is important for understanding data patterns and making informed decisions during analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the correlation heatmap of numerical features in the dataset from the Google Play Store, the following insights were observed:
#
# Most variables show weak or low correlation, indicating that they are largely independent of each other.
#
# The Rating variable does not have a strong correlation with other numerical features (such as review length, if included), suggesting that user ratings are influenced by multiple factors rather than a single measurable variable.
#
# If a slight negative or positive correlation exists (e.g., between rating and review length), it indicates a minor relationship, but not strong enough to draw direct conclusions.
#
# The absence of strong correlations suggests that user behavior is complex and multi-dimensional, and cannot be explained by a single factor.
#
# Key Insight
#
# There is no strong linear relationship between numerical variables, indicating that user ratings and behavior depend on multiple independent factors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the correlation heatmap of the dataset from the Google Play Store can support positive business impact.
#
# The finding that most variables have weak correlations indicates that user ratings are influenced by multiple independent factors rather than a single metric. This encourages businesses to take a holistic approach—improving performance, usability, features, and overall user experience instead of focusing on just one area.
#
# It helps decision-makers avoid oversimplified assumptions, leading to more accurate and data-driven strategies for improving app quality and user satisfaction.
#
# However, there are also insights that may lead to negative growth if misunderstood or ignored:
#
# Since no single factor strongly influences ratings, focusing improvement efforts on just one aspect (e.g., only increasing features but ignoring performance) may not significantly improve user satisfaction.
#
# Misinterpreting weak correlations as “no problem” could lead to neglecting important user issues, resulting in continued dissatisfaction, negative reviews, and reduced retention.
# Lack of clear relationships may make it harder to identify priority areas, and without proper analysis, this can lead to inefficient decision-making and wasted resources.
#
# Conclusion
#
# These insights highlight the need for a comprehensive improvement strategy. Addressing multiple aspects of the app simultaneously is essential for sustainable growth.Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# Group data by App
app_data = df.groupby('App').agg({
    'Reviews': 'count',
        'Rating': 'mean'
        }).reset_index()

        # Rename columns for clarity
app_data.columns = ['App', 'Review_Count', 'Avg_Rating']

        # Plot scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x='Review_Count', y='Avg_Rating', data=app_data)

plt.title("Number of Reviews vs Average Rating")
plt.xlabel("Number of Reviews")
plt.ylabel("Average Rating")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This scatter plot is powerful because it brings together two critical aspects of app performance—user engagement (number of reviews) and user satisfaction (average rating)—in a single view.
#
# Using data from the Google Play Store, this chart allows us to:
#
# Identify top-performing apps that have both high review counts and high ratings, indicating strong popularity and user satisfaction.
#
# Detect problem areas, such as apps with high reviews but low ratings, which suggests many users are experiencing issues.
#
# Understand whether there is any relationship between engagement and satisfaction, helping in deeper analysis of user behavior.
#
# Visually segment apps into groups (high-high, high-low, low-high), making it easier for businesses to prioritize actions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatter plot showing the relationship between number of reviews and average rating in the dataset from the Google Play Store, the following insights were observed:
#
# Apps with high review counts and high ratings represent top-performing apps, indicating both strong popularity and high user satisfaction.
#
# Some apps have high review counts but lower average ratings, suggesting that while they are widely used, users may be facing issues or dissatisfaction.
# Apps with low review counts but high ratings may be niche or new apps that have good quality but lower visibility.
#
# There is no strong linear relationship between number of reviews and ratings, indicating that higher engagement does not always guarantee better user satisfaction.
#
# Key Insights
#
# Popularity and user satisfaction do not always go hand in hand—some highly used apps may still have lower ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the relationship between number of reviews and average rating in the dataset from the Google Play Store can create a strong positive business impact.
#
# Apps that show high review counts along with high ratings indicate both strong popularity and user satisfaction. These apps can be used as benchmarks to understand successful strategies, helping businesses improve product quality and user experience.
# Identifying apps with high ratings but low review counts can help businesses focus on marketing and visibility, as these apps have potential for growth but are currently underexposed.
# This analysis supports data-driven decision-making, allowing companies to balance both engagement and quality for better outcomes.
#
# However, there are also insights that may lead to negative growth if not addressed:
#
# Apps with high review counts but low average ratings indicate widespread usage but poor user satisfaction. If these issues are ignored, it can lead to negative reviews, poor ratings, reduced user trust, and higher uninstall rates.
#
# Since these apps already have a large user base, negative feedback can spread quickly and significantly impact brand reputation and future growth.
#
# The lack of a strong relationship between reviews and ratings suggests that simply increasing user engagement without improving quality may not lead to better outcomes.
#
# Conclusion
#
# These insights highlight the importance of balancing user engagement with user satisfaction. Focusing on both aspects is essential for sustainable business growth.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# Plot
plt.figure(figsize=(8,5))
sns.countplot(x='Rating', data=df)

plt.title("Number of Reviews per Rating")
plt.xlabel("Rating")
plt.ylabel("Number of Reviews")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is better because it goes beyond simple frequency distribution and provides deeper behavioral insights about users.
#
# Using data from the Google Play Store, this chart:
#
# Shows how user behavior changes with ratings, not just how many ratings exist.
#
# Highlights the average effort users put into reviews at each rating level
# Helps identify patterns such as whether dissatisfied users write longer feedback compared to satisfied users.
#
# Avoids repetition if a basic rating distribution chart has already been used earlier.
#
# Unlike a simple count plot, this chart adds analytical depth by connecting ratings with review behavior, making your EDA more insightful and less repetitive.
#
# Key Value
#
# It transforms basic data into meaningful insights by showing how users behave, not just what they rate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart showing average review length per rating in the dataset from the Google Play Store, the following insights were observed:
#
# Lower ratings (1 and 2) have higher average review lengths, indicating that dissatisfied users tend to write more detailed feedback.
#
# Higher ratings (4 and 5) have shorter average review lengths, suggesting that satisfied users usually give brief and quick responses.
#
# There is a clear inverse pattern between rating and review length, where review length decreases as ratings increase.
#
# This behavior shows that users are more expressive when they face problems, while positive experiences are often shared concisely.
#
# Key Insight
#
# Users who are dissatisfied tend to provide more detailed feedback, while satisfied users give shorter reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the average review length per rating in the dataset from the Google Play Store can create a meaningful positive business impact.
#
# Since low-rated reviews are longer and more detailed, they provide valuable and specific feedback about user problems. Businesses can use this information to identify key issues such as bugs, poor performance, or usability challenges and take targeted actions to improve the app.
#
# Addressing these detailed complaints can lead to better user satisfaction, higher ratings, and improved retention, ultimately driving growth.
# It also helps prioritize customer support and development efforts by focusing on the most critical issues highlighted by users.
#
# However, there are also insights that may lead to negative growth if ignored:
# The presence of detailed negative reviews indicates strong user dissatisfaction. If these issues are not resolved, it can lead to negative word-of-mouth, poor ratings, and reduced downloads.
#
# Since these reviews are detailed, they are more likely to influence potential users, discouraging them from installing the app.
#
# Ignoring such feedback can result in loss of user trust and competitive disadvantage, as users may switch to better-performing apps.
#
# Conclusion
#
# These insights are highly valuable for improving app quality, but only if acted upon. Addressing detailed user complaints is essential for sustaining growth and maintaining a positive user experience.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Step 1: Group data by App
app_stats = df.groupby('App').agg({
    'Rating': 'mean',
        'Reviews': 'count'
        }).reset_index()

        # Rename columns
app_stats.columns = ['App', 'Avg_Rating', 'Review_Count']

        # Step 2: Filter apps with at least 50 reviews (avoid bias)
app_filtered = app_stats[app_stats['Review_Count'] >= 50]

        # Step 3: Get top 10 apps by rating
top_rated_apps = app_filtered.sort_values(by='Avg_Rating', ascending=False).head(10)

        # Step 4: Plot
plt.figure(figsize=(10,6))
sns.barplot(x='Avg_Rating', y='App', data=top_rated_apps)

plt.title("Top 10 Apps with Highest Average Rating (Min 50 Reviews)")
plt.xlabel("Average Rating")
plt.ylabel("App Name")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is powerful because it identifies truly high-performing apps by combining both quality (average rating) and reliability (minimum number of reviews).
#
# Using data from the Google Play Store, this chart:
#
# Eliminates bias by filtering out apps with very few reviews, ensuring that only apps with sufficient user feedback are considered.
#
# Highlights apps that consistently deliver high user satisfaction, making them reliable benchmarks for success
# Helps distinguish between apps that are highly rated due to genuine performance versus those with artificially high ratings from limited data.
#
# Provides a clear view of top-performing apps, which can guide product strategy, feature development, and competitive analysis.
#
# Key Value
#
# It ensures that insights are based on trustworthy and meaningful data, not misleading high ratings from a small number of users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart showing the top apps with the highest average ratings (with a minimum review threshold) in the dataset from the Google Play Store, the following insights were observed:
#
# The identified apps maintain consistently high ratings along with a sufficient number of reviews, indicating reliable and genuine user satisfaction.
#
# These apps are likely delivering high-quality performance, good user experience, and strong functionality, which contributes to their high ratings.
#
# The filtering condition (minimum reviews) ensures that the results are not biased by apps with very few users, making the insights more trustworthy.
#
# These top-performing apps can act as benchmarks for understanding successful strategies in terms of features, usability, and performance.
#
# Key Insight
#
# The chart highlights apps that are not only highly rated but also consistently appreciated by a large number of users, making them truly reliable top performers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from identifying top apps with high average ratings and sufficient reviews in the Google Play Store can create a strong positive business impact.
#
# These apps represent reliable high performers, as they have both strong user satisfaction and a significant number of users. Businesses can use them as benchmarks to understand best practices in terms of features, usability, and performance.
#
# By analyzing these successful apps, companies can replicate effective strategies, improve their own apps, and enhance overall user experience.
# This insight also helps in strategic planning and competitive analysis, allowing businesses to focus on what truly drives user satisfaction and retention.
#
# However, there are also insights that may lead to negative growth if not considered carefully:
# Focusing only on top-performing apps may lead businesses to ignore low-performing apps or segments, where improvements are actually needed the most.
#
# If companies try to replicate top apps without understanding their unique context, it may result in ineffective or misaligned strategies.
#
# Ignoring apps with lower ratings but high potential could result in missed growth opportunities and reduced competitiveness.
#
# Conclusion
#
# While these insights are valuable for identifying success patterns, businesses must balance their focus by also addressing weaker areas to ensure overall growth.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

plt.figure(figsize=(8,5))

sns.histplot(df['Rating'], bins=5, kde=True)

plt.title("Distribution of Ratings")
plt.xlabel("Rating")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This histogram with KDE is useful because it provides a clear overall picture of how user ratings are distributed in the dataset from the Google Play Store.
#
# It helps visualize whether ratings are skewed toward positive, negative, or neutral feedback.
#
# The histogram shows the frequency of each rating, making it easy to see which ratings are most common.
#
# The KDE (smooth curve) helps identify the overall trend of user sentiment, making the pattern easier to understand compared to raw numbers.
#
# It acts as a summary chart, combining all rating behavior into a single visual representation.
#
# It is especially useful in EDA because it gives a quick understanding of overall user satisfaction level in the dataset.
#
# Key Value
#
# This chart helps quickly understand the overall sentiment trend of users in one view, making it a strong summary visualization for the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the histogram with KDE showing rating distribution in the dataset from the Google Play Store, the following insights were observed:
#
# The distribution is skewed towards higher ratings (4 and 5), indicating that most users are generally satisfied with the apps.
#
# Lower ratings (1 and 2) appear less frequently, showing that a smaller portion of users had negative experiences.
#
# The peak of the distribution is around high ratings, which reflects a positive overall sentiment in the dataset.
#
# The smooth KDE curve confirms a strong concentration of ratings on the higher end, rather than a balanced or normal distribution.
#
# This pattern suggests that most apps in the dataset are performing well in terms of user satisfaction.
#
# Key Insight
#
# Overall user sentiment is positive, with most ratings clustered around high values (4 and 5), indicating general satisfaction among users.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the rating distribution chart of the dataset from the Google Play Store can create a strong positive business impact.
#
# The fact that most ratings are concentrated around 4 and 5 indicates overall high user satisfaction. This is beneficial for businesses as it improves app credibility, user trust, and visibility on the Play Store, which can lead to higher downloads and retention.
#
# A positive rating trend also helps in brand reputation building, as new users are more likely to install apps with better ratings.
#
# Businesses can use this insight to understand that their current features and services are generally meeting user expectations.
#
# However, there are also insights that may lead to negative growth if not addressed carefully:
#
# Even though lower ratings are fewer, the presence of 1 and 2-star ratings indicates user dissatisfaction. If these issues are ignored, they can lead to negative reviews, uninstallations, and reduced user trust.
#
# Negative experiences, even from a small group of users, can impact overall perception, especially since users often check low ratings before downloading an app.
#
# If the reasons behind low ratings (such as bugs, crashes, or poor performance) are not resolved, it can slow down future growth.
#
# Conclusion
#
# The insights show strong growth potential due to overall positive ratings, but addressing negative feedback is essential to maintain long-term success and prevent loss of users.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# Top 10 apps by number of reviews
top_reviews = df['App'].value_counts().head(10)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=top_reviews.values, y=top_reviews.index)

plt.title("Top 10 Apps with Most Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("App Name")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is useful because it clearly identifies the most engaged apps based on user interaction in the dataset from the Google Play Store.
#
# It helps highlight apps that receive the highest number of user reviews, which is a strong indicator of popularity and active usage.
#
# It provides a clear comparison between apps, making it easy to see which apps dominate user attention.
#
# It helps businesses understand which apps generate the most feedback, which is valuable for improving features and fixing issues.
#
# It supports decision-making by identifying high-engagement apps that should be prioritized for analysis or improvement.
#
# It simplifies large data into a clear ranking format, making insights easy to interpret.
#
# Key Value
#
# This chart is useful because it shows user engagement levels and helps identify the most influential and widely used apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart showing the top 10 apps with the highest number of reviews in the dataset from the Google Play Store, the following insights were observed:
#
# A small number of apps receive a very large volume of reviews, indicating that user engagement is concentrated among a few popular apps.
#
# These apps are likely the most widely used and downloaded, as higher review counts usually reflect higher user interaction.
#
# The distribution is highly uneven, meaning most apps receive relatively fewer reviews compared to the top-performing ones.
#
# Apps with the highest reviews are important because they generate the majority of user feedback, making them critical for analysis and improvement.
#
# High review counts suggest these apps have a strong market presence and user base, but they may also require continuous monitoring due to large-scale user feedback.
#
# Key Insight
#
# User engagement is heavily concentrated in a few top apps, making them the most important for understanding user behavior and market trends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the “Top Apps with Most Reviews” analysis of the dataset from the Google Play Store can create a strong positive business impact.
#
# Apps with very high review counts indicate strong user engagement and popularity. Businesses can focus on these apps to understand what features, design, and performance factors are attracting users.
#
# These apps generate a large amount of feedback, which can be used to improve product quality, fix issues faster, and enhance user experience.
#
# High-engagement apps can also help in marketing strategies and business growth planning, as they represent the most active user base.
#
# However, there are also insights that may lead to negative growth if not managed properly:
#
# Apps with very high review counts may also receive a large number of negative reviews, which can impact their overall rating and reputation if issues are not resolved.
#
# Since user feedback is concentrated in a few apps, any performance issues or bugs in these apps can affect a large number of users, leading to uninstallations and loss of trust.
#
# Over-reliance on a few popular apps can be risky; if their performance declines, it may result in a significant drop in overall business performance and revenue.
#
# Conclusion
#
# These insights are valuable for identifying key high-impact apps, but businesses must continuously improve them and not ignore negative feedback to ensure sustainable growth.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Step 1: Compute average rating and review count per app
app_stats = df.groupby('App').agg({
    'Rating': 'mean',
        'Reviews': 'count'
        }).reset_index()

app_stats.columns = ['App', 'Avg_Rating', 'Review_Count']

        # Step 2: Filter apps with minimum 50 reviews (for reliability)
filtered_apps = app_stats[app_stats['Review_Count'] >= 50]

        # Step 3: Top 10 apps by rating
top_apps = filtered_apps.sort_values(by='Avg_Rating', ascending=False).head(10)

        # Step 4: Plot
plt.figure(figsize=(10,6))
sns.barplot(x='Avg_Rating', y='App', data=top_apps)

plt.title("Top 10 Apps with Highest Average Rating (Min 50 Reviews)")
plt.xlabel("Average Rating")
plt.ylabel("App Name")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is important because it identifies the most reliable and genuinely high-performing apps in the dataset from the Google Play Store, rather than just showing apps with high ratings alone.
#
# It combines quality (average rating) with trust (minimum number of reviews), making the results more meaningful and less biased.
#
# It removes the problem of misleading high ratings from apps with very few reviews, which can distort analysis.
#
# It helps identify apps that are consistently well-rated by a large number of users, which is a strong indicator of real user satisfaction.
#
# It provides benchmark apps, which businesses can study to understand what makes an app successful in terms of performance and user experience.
#
# It supports better decision-making, as it focuses on apps with both popularity and reliability.
#
# Key Value
#
# This chart is important because it highlights truly trustworthy top-performing apps based on both user satisfaction and sufficient user feedback.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart showing top apps with the highest average ratings (with a minimum number of reviews) in the dataset from the Google Play Store, the following insights were observed:
#
# The top apps maintain consistently high ratings along with sufficient user feedback, indicating strong and reliable user satisfaction.
#
# These apps are not just popular, but also trusted by a large number of users, which makes their ratings more credible.
#
# Apps with high ratings and enough reviews suggest stable performance, good usability, and positive user experience over time.
#
# The filtering of minimum reviews ensures that the results are not biased by apps with very few ratings, making insights more realistic.
#
# These apps can be considered benchmark performers, representing best practices in app design and functionality.
#
# Key Insight
#
# Truly successful apps are those that maintain high ratings consistently across a large user base, not just apps with limited feedback.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from identifying top apps with the highest average ratings (with a minimum review threshold) in the dataset from the Google Play Store can create a strong positive business impact.
#
# These apps represent consistent high performance and strong user satisfaction, making them ideal benchmarks for understanding what leads to success.
#
# Businesses can analyze these apps to identify best practices in design, functionality, performance, and user experience, and apply similar strategies to their own products.
#
# Since these apps have enough reviews, the insights are reliable and not biased, helping in accurate decision-making.
#
# This can lead to improved app quality, better user retention, higher ratings, and increased downloads, driving overall business growth.
#
# However, there are also insights that may lead to negative growth if misused or ignored:
#
# Focusing only on top-rated apps may cause businesses to ignore low-performing apps, where improvement is actually needed the most.
#
# Copying features from top apps without understanding user context may lead to ineffective strategies or poor user experience.
#
# Ignoring apps with lower ratings but high potential can result in missed opportunities for innovation and market expansion.
#
# Conclusion
#
# These insights are highly valuable for identifying success factors, but businesses must balance focus between high-performing and low-performing apps to ensure sustainable growth.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# Aggregate data per app
app_data = df.groupby('App').agg({
    'Rating': 'mean',
        'Reviews': 'count'
        }).reset_index()

app_data.columns = ['App', 'Avg_Rating', 'Review_Count']

        # Plot scatter
plt.figure(figsize=(8,6))
sns.scatterplot(x='Avg_Rating', y='Review_Count', data=app_data)

plt.title("Rating vs Review Count")
plt.xlabel("Average Rating")
plt.ylabel("Number of Reviews")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is useful because it helps understand the relationship between user satisfaction and user engagement in a single view for the dataset from the Google Play Store.
#
# It combines two key business metrics: average rating (quality) and number of reviews (popularity).
#
# It helps identify whether popular apps are also well-rated, or if high usage comes with user dissatisfaction.
#
# It allows quick classification of apps into groups like:
#
# High rating + high reviews (best performers)
#
# High reviews + low rating (problematic but popular apps)
#
# Low reviews + high rating (good but less visible apps)
#
# It provides a clear visual relationship between engagement and satisfaction, which is important for decision-making.
#
# It helps businesses understand whether increasing usage also leads to better user experience or not.
#
# Key Value
#
# This chart is useful because it connects popularity and satisfaction, helping identify both successful apps and apps that need improvement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatter plot showing the relationship between average rating and number of reviews in the dataset from the Google Play Store, the following insights were observed:
#
# There is no strong linear relationship between rating and number of reviews, meaning popularity does not always guarantee higher satisfaction.
#
# Some apps have high review counts but average or low ratings, indicating that many users use the app but are not fully satisfied.
#
# A few apps show high ratings with fewer reviews, suggesting good quality but lower visibility or reach.
#
# Apps with both high ratings and high reviews represent the best-performing category, combining strong user satisfaction with strong engagement.
#
# The distribution is scattered, showing that user engagement and satisfaction are influenced by multiple independent factors, not just one variable.
#
# Key Insight
#
# Popularity and user satisfaction are not directly proportional—apps can be widely used but still receive mixed or poor ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the relationship between rating and review count in the dataset from the Google Play Store can create a strong positive business impact.
#
# The analysis helps identify high-performing apps that balance both popularity and user satisfaction, which can be used as benchmarks for improving other apps.
#
# Apps with high ratings and high engagement indicate successful product strategies, which businesses can study to improve features, usability, and performance.
#
# Understanding that engagement and satisfaction are not always linked helps companies make better data-driven decisions instead of assuming that popular apps are automatically successful.
#
# It also helps in prioritizing improvements, focusing on apps that have high usage but need better user experience.
#
# However, there are also insights that may lead to negative growth if ignored:
# Apps with high review counts but low ratings indicate widespread dissatisfaction. If not addressed, this can lead to negative reviews, reduced trust, and app uninstallations.
# Since these apps are widely used, negative feedback can spread quickly, impacting the brand reputation on a large scale.
#
# Ignoring the mismatch between popularity and satisfaction can result in loss of loyal users and declining long-term growth.
#
# Conclusion
#
# These insights are valuable for improving both product quality and user experience, but businesses must carefully address dissatisfaction in popular apps to avoid negative growth.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Select numeric columns only
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Correlation matrix
corr = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap was chosen because it helps to understand the relationship between different numerical variables in the dataset from the Google Play Store in a simple and visual way.
#
# It clearly shows how strongly variables are related to each other using color intensity.
#
# It helps identify whether variables have a positive, negative, or no relationship.
#
# It simplifies complex numerical relationships into an easy-to-understand visual format.
#
# It is useful in EDA to quickly detect patterns and dependencies between features before deeper analysis.
#
# It supports better decision-making by showing whether changes in one variable may affect another.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the correlation heatmap of numerical variables in the dataset from the Google Play Store, the following insights were observed:
#
# Most variables show weak or very low correlation, meaning they are largely independent of each other.
#
# There is no strong positive or negative relationship between key numerical features, indicating that no single variable strongly influences another.
#
# The weak correlation between features like rating and other numerical fields suggests that user satisfaction is influenced by multiple factors, not just one measurable metric.
#
# The absence of strong correlations indicates that the dataset has complex user behavior patterns, where relationships are not linear or direct.
#
# This also suggests that relying on a single feature for prediction or analysis would not be sufficient for understanding user behavior.
#
# Key Insight
#
# There are no strong correlations between variables, showing that app performance and user behavior depend on multiple independent factors.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code


# Select numeric columns only
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Pair plot
sns.pairplot(numeric_df)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pair plot was chosen because it provides a comprehensive visual analysis of relationships between multiple numerical variables in the dataset from the Google Play Store in a single view.
#
# It allows us to see pairwise relationships between all numerical features at once, instead of analyzing them one by one.
#
# It helps identify patterns, trends, and possible correlations between variables through scatter plots.
#
# The diagonal plots show the distribution of each variable, helping understand how data is spread.
#
# It is useful for detecting outliers and unusual data behavior visually.
#
# It gives a quick overall understanding of dataset structure, which is important in exploratory data analysis (EDA).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the pair plot of numerical variables in the dataset from the Google Play Store, the following insights were observed:
#
# Most variable pairs show no clear linear relationship, indicating weak or no strong correlation between numerical features.
#
# The scatter plots are widely spread, suggesting that user behavior and app performance are influenced by multiple independent factors.
#
# The diagonal distributions show that some variables are skewed, meaning data is not evenly distributed across all values.
#
# A few clusters may appear in certain plots, indicating some grouping behavior among apps, but not strong enough to form a clear pattern.
#
# Presence of scattered points suggests possible outliers, which may affect overall analysis if not handled properly.
#
# Key Insight
#
# There are no strong relationships between variables, and the data shows scattered patterns with possible skewness and outliers.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the exploratory data analysis of the Google Play Store dataset, here are the key suggestions to achieve better business outcomes:
#
# 1. Focus on User Satisfaction (Ratings Improvement)
#
# Apps with higher ratings perform better in long-term success. The client should:
#
# Improve app performance, speed, and usability.
#
# Fix bugs and reduce crashes
# Regularly update apps based on user feedback
#
# 2. Monitor Highly Reviewed Apps Closely
# Apps with high reviews represent maximum user engagement:
#
# Prioritize these apps for maintenance and updates.
#
# Act quickly on negative feedback to protect reputation.
#
# Use reviews to identify real user problems.
#
# 3. Improve Low-Rated but Highly Used Apps.
# Some apps show high usage but lower ratings:
#
# These are high-risk apps
# Improving them can lead to major growth in retention and ratings
# Focus on UI/UX improvements and feature optimization
#
# 4. Balance Popularity and Quality
# Success is not only about downloads:
#
# Ensure apps are both widely used and well-rated.
#
# Avoid focusing only on marketing without improving quality.
#
# 5. Use Data-Driven Decisions
# Continuously analyze rating, reviews, and trends.
#
# Identify patterns before making product changes.
#
# Use EDA insights for strategic planning.
#
# Final Conclusion
#
# To achieve business objectives, the client should focus on improving user satisfaction, continuously monitor high-engagement apps, and ensure a balance between popularity and quality. This will lead to better ratings, higher retention, and sustainable growth.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Based on the exploratory data analysis of the Google Play Store dataset, here are the key suggestions to achieve better business outcomes:
#
# 1. Focus on User Satisfaction (Ratings Improvement)
#
# Apps with higher ratings perform better in long-term success. The client should:
#
# Improve app performance, speed, and usability.
#
# Fix bugs and reduce crashes
# Regularly update apps based on user feedback.
#
# 2. Monitor Highly Reviewed Apps Closely
# Apps with high reviews represent maximum user engagement:
#
# Prioritize these apps for maintenance and updates.
#
# Act quickly on negative feedback to protect reputation.
#
# Use reviews to identify real user problems.
#
# 3. Improve Low-Rated but Highly Used Apps
#
# Some apps show high usage but lower ratings:
#
# These are high-risk apps
# Improving them can lead to major growth in retention and ratings
# Focus on UI/UX improvements and feature optimization
#
# 4. Balance Popularity and Quality
# Success is not only about downloads:
#
# Ensure apps are both widely used and well-rated.
#
# Avoid focusing only on marketing without improving quality.
#
# 5. Use Data-Driven Decisions
# Continuously analyze rating, reviews, and trends.
#
# Identify patterns before making product changes.
#
# Use EDA insights for strategic planning.
#
# Final Conclusion
#
# To achieve business objectives, the client should focus on improving user satisfaction, continuously monitor high-engagement apps, and ensure a balance between popularity and quality. This will lead to better ratings, higher retention, and sustainable growth.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
