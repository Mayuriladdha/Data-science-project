# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayuriladdha/Data-science-project/blob/main/EDA_project_of_Amazon_Prime_TV_Shows_and_Movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Amazon Prime TV Shows and Movies

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Mayuri Laddha

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# With the rapid growth of online streaming platforms, understanding content distribution and audience preferences has become increasingly important for making informed business decisions. Amazon Prime Video hosts a vast library of movies and TV shows spanning multiple genres, countries, languages, and release years. Analyzing this content can reveal valuable insights into production trends, content diversity, and the platform's overall content strategy.
#
# The primary objective of this project is to perform an in-depth Exploratory Data Analysis (EDA) on the Amazon Prime TV Shows and Movies dataset to uncover meaningful patterns and generate actionable business insights. The project utilizes two datasets: titles.csv, which contains detailed information about each title such as type, genre, release year, runtime, age certification, IMDb ratings, TMDb ratings, production countries, and popularity, and credits.csv, which contains information about the cast and crew associated with each title.
#
# The analysis begins with understanding the structure of the datasets, identifying data types, detecting missing values, and removing duplicate records to ensure high data quality. Appropriate preprocessing techniques are applied wherever necessary, including handling null values, converting data into suitable formats, and preparing the datasets for analysis.
#
# A comprehensive exploratory analysis is then performed using Python libraries such as Pandas, NumPy, Matplotlib, and Seaborn. Various visualizations are created to examine the distribution of movies and TV shows, content growth over time, genre popularity, runtime patterns, IMDb and TMDb ratings, age certifications, production countries, and other important characteristics. Relationships between different variables are also explored to understand how various factors influence content quality and popularity.
#
# The analysis further investigates trends such as the evolution of content production across different decades, the most frequently produced genres, highly rated titles, country-wise content contribution, and differences between movies and TV shows. By combining statistical summaries with informative visualizations, the project provides a clear understanding of Amazon Prime Video's content library and highlights important business trends.
#
# The findings of this project can help streaming platforms, content creators, production companies, and business analysts make data-driven decisions regarding content acquisition, production planning, audience targeting, and catalog expansion. The insights also demonstrate how exploratory data analysis can transform raw entertainment data into meaningful information that supports strategic decision-making.
#
# Overall, this project showcases the complete EDA workflow—from data understanding and preprocessing to visualization, insight generation, and business recommendations. It emphasizes the importance of data analysis in the entertainment industry and illustrates how data-driven strategies can enhance content management, improve user engagement, and support long-term business growth.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The rapid expansion of online streaming platforms has led to the availability of vast amounts of entertainment content, making it challenging for businesses to understand content trends, audience preferences, and catalog diversity. Amazon Prime Video hosts thousands of movies and TV shows across different genres, countries, languages, and release years. However, without systematic analysis, it is difficult to identify patterns in content production, popularity, ratings, runtime, and regional distribution that can support strategic decision-making.
#
# The objective of this project is to perform a comprehensive Exploratory Data Analysis (EDA) on the Amazon Prime TV Shows and Movies dataset to uncover meaningful insights into the platform's content library. The analysis aims to examine content distribution, identify trends over time, evaluate genre popularity, analyze audience ratings, study production across different countries, and compare the characteristics of movies and TV shows.
#
# By transforming raw data into clear visualizations and actionable insights, this project seeks to provide valuable information that can assist content creators, business analysts, and streaming platforms in optimizing content acquisition, improving recommendation strategies, understanding audience interests, and making data-driven decisions to enhance user engagement and long-term business growth.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The primary business objective of this project is to analyze Amazon Prime Video's content library to uncover meaningful patterns, trends, and insights that can support strategic business decisions. By performing Exploratory Data Analysis (EDA) on the dataset, the project aims to understand the distribution of movies and TV shows, identify popular genres, analyze content growth over time, evaluate audience ratings, examine production across different countries, and assess content characteristics such as runtime and age certification.
#
# The insights generated from this analysis can help streaming platforms optimize content acquisition strategies, identify high-performing genres and regions, improve content recommendations, understand audience preferences, and maintain a diverse and engaging content catalog. Additionally, the findings can support production planning, marketing strategies, and investment decisions by highlighting trends in viewer-rated content and content availability across different categories.
#
# Ultimately, this project demonstrates how data-driven analysis can transform raw entertainment data into actionable business intelligence, enabling streaming platforms to enhance customer satisfaction, improve user engagement, and strengthen their competitive position in the digital entertainment industry.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# Import libraries for data manipulation
import pandas as pd
import numpy as np

# Import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Configure visualization settings
# %matplotlib inline
plt.style.use('ggplot')
sns.set_theme(style="whitegrid")

# Ignore unnecessary warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
titles_df = pd.read_csv('/content/titles.csv')
credits_df = pd.read_csv('/content/credits.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

# Display the first 5 rows of the titles dataset
titles_df.head()
# Display the first 5 rows of the credits dataset
credits_df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

# Check the number of rows and columns in the titles dataset
print("Titles Dataset Shape:", titles_df.shape)
print("Number of Rows:", titles_df.shape[0])
print("Number of Columns:", titles_df.shape[1])

# Check the number of rows and columns in the credits dataset
print("\nCredits Dataset Shape:", credits_df.shape)
print("Number of Rows:", credits_df.shape[0])
print("Number of Columns:", credits_df.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information

# Information about the Titles dataset
print("Titles Dataset Information:")
titles_df.info()

print("\n" + "="*60 + "\n")

# Information about the Credits dataset
print("Credits Dataset Information:")
credits_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Duplicate Values

# Check duplicate values in the Titles dataset
print("Duplicate Rows in Titles Dataset:", titles_df.duplicated().sum())

# Check duplicate values in the Credits dataset
print("Duplicate Rows in Credits Dataset:", credits_df.duplicated().sum())

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Missing Values / Null Values

# Check missing values in the Titles dataset
print("Missing Values in Titles Dataset:")
titles_df.isnull().sum()
# Check missing values in the Credits dataset
print("Missing Values in Credits Dataset:")
credits_df.isnull().sum()

# %%
# Visualizing the missing values
# Visualize missing values using a heatmap

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))
sns.heatmap(titles_df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values in Titles Dataset")
plt.show()

plt.figure(figsize=(10,5))
sns.heatmap(credits_df.isnull(), cbar=False, cmap='viridis')
plt.title("Missing Values in Credits Dataset")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset consists of two files: titles.csv and credits.csv. The titles dataset contains detailed information about Amazon Prime Video content, including movies and TV shows, with features such as title, content type, release year, runtime, genres, production countries, age certification, IMDb and TMDb ratings, popularity, and votes. The credits dataset contains information about the cast and crew, including the names of actors and directors, their roles, and the titles they are associated with.
#
# Initial exploration showed that the datasets contain a mix of numerical and categorical variables. Some columns have missing values, particularly those related to age certification, descriptions, ratings, and production details, which require appropriate preprocessing before analysis. Duplicate records were also checked to ensure data quality.
#
# Overall, the datasets are rich and comprehensive, providing sufficient information to analyze content distribution, genre trends, audience ratings, production patterns, and other key characteristics of Amazon Prime's catalog. These datasets are well suited for performing Exploratory Data Analysis (EDA) and generating valuable business insights.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

# Columns in the Titles dataset
print("Titles Dataset Columns:\n")
print(titles_df.columns.tolist())

print("\n" + "="*80 + "\n")

# Columns in the Credits dataset
print("Credits Dataset Columns:\n")
print(credits_df.columns.tolist())

# %%
# Dataset Describe

# Statistical summary of the Titles dataset
print("Titles Dataset Description:")
titles_df.describe(include='all').T

print("\n" + "="*80 + "\n")

# Statistical summary of the Credits dataset
print("Credits Dataset Description:")
credits_df.describe(include='all').T

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Titles Dataset Variables
#
#
# - Variable| Description
# - "id"| Unique identifier for each title.
# - "title"| Name of the movie or TV show.
# - "type"| Indicates whether the content is a Movie or a TV Show.
# - "description"| Brief summary or storyline of the title.
# - "release_year"| Year in which the title was originally released.
# - "age_certification"| Recommended age rating (e.g., PG, R, TV-MA).
# - "runtime"| Duration of the movie or episode in minutes.
# - "genres"| Genre(s) associated with the title.
# - "production_countries"| Country or countries where the title was produced.
# - "seasons"| Number of seasons (applicable mainly to TV shows).
# - "imdb_id"| Unique IMDb identifier for the title.
# - "imdb_score"| IMDb user rating of the title.
# - "imdb_votes"| Number of votes received on IMDb.
# - "tmdb_popularity"| Popularity score assigned by TMDb.
# - "tmdb_score"| Average user rating on TMDb.
#
#
# Credits Dataset Variables
#
#
# - Variable| Description
# - "person_id"| Unique identifier for the cast or crew member.
# - "id"| Unique identifier linking the person to a title.
# - "name"| Name of the actor, actress, director, or crew member.
# - "character"| Character portrayed by the actor (if applicable).
# - "role"| Role of the individual in the title (e.g., Actor, Director).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for Each Variable

# Unique values in Titles dataset
print("Unique Values in Titles Dataset:\n")
for col in titles_df.columns:
    print(f"{col}: {titles_df[col].nunique()} unique values")

    print("\n" + "="*60 + "\n")

    # Unique values in Credits dataset
    print("Unique Values in Credits Dataset:\n")
    for col in credits_df.columns:
        print(f"{col}: {credits_df[col].nunique()} unique values")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# ==========================
# Data Wrangling Code
# ==========================

# Create copies of the original datasets
titles = titles_df.copy()
credits = credits_df.copy()

# Check dataset shapes
print("Titles Shape:", titles.shape)
print("Credits Shape:", credits.shape)

# Check duplicate values
print("\nDuplicate Rows in Titles:", titles.duplicated().sum())
print("Duplicate Rows in Credits:", credits.duplicated().sum())

# Remove duplicate rows
titles.drop_duplicates(inplace=True)
credits.drop_duplicates(inplace=True)

# Check missing values
print("\nMissing Values in Titles Dataset:")
print(titles.isnull().sum())

print("\nMissing Values in Credits Dataset:")
print(credits.isnull().sum())

# Convert release_year to integer (if required)
titles['release_year'] = titles['release_year'].astype('Int64')

# Convert runtime to numeric
titles['runtime'] = pd.to_numeric(titles['runtime'], errors='coerce')

# Fill missing values
titles['age_certification'].fillna('Not Rated', inplace=True)
titles['description'].fillna('No Description', inplace=True)
titles['seasons'].fillna(0, inplace=True)

credits['character'].fillna('Unknown', inplace=True)

# Verify data types
print("\nTitles Data Types:")
print(titles.dtypes)

print("\nCredits Data Types:")
print(credits.dtypes)

# Final dataset shape
print("\nFinal Titles Shape:", titles.shape)
print("Final Credits Shape:", credits.shape)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# What all manipulations have you done and insights you found?
#
# During the data wrangling process, both the titles and credits datasets were carefully examined and prepared for analysis. Duplicate records were identified and removed to ensure data consistency. Missing values were analyzed, and appropriate treatments were applied by filling categorical columns such as age certification, description, and character with meaningful placeholders, while missing values in seasons were replaced with "0" where applicable. Data types were verified and corrected, with columns such as release_year and runtime converted into appropriate numeric formats for accurate analysis.
#
# Additionally, copies of the original datasets were created to preserve the raw data, ensuring that all preprocessing steps were performed on separate working datasets. The datasets were then validated to confirm that they were clean and ready for exploratory data analysis.
#
# Insights Found:
#
# - The datasets contained a small number of duplicate records, which were removed to improve data quality.
# - Several columns had missing values, particularly those related to age certification, descriptions, and character names, indicating that not all titles have complete metadata.
# - The datasets include both numerical and categorical variables, making them suitable for a wide range of statistical analyses and visualizations.
# - After preprocessing, the data became more consistent, reliable, and suitable for generating meaningful business insights through Exploratory Data Analysis (EDA).

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart 1: Distribution of Content Type (Movies vs TV Shows)

plt.figure(figsize=(8,6))

sns.countplot(x='type', data=titles_df, palette='Set2')

plt.title('Distribution of Movies and TV Shows on Amazon Prime', fontsize=15)
plt.xlabel('Content Type')
plt.ylabel('Count')

for container in plt.gca().containers:
    plt.bar_label(container)

    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot was selected because the variable type (Movie or TV Show) is categorical. Count plots are ideal for comparing the frequency of different categories and provide a simple, clear visualization of the content distribution on Amazon Prime Video.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the proportion of Movies and TV Shows available on Amazon Prime Video.
#
# It helps identify which content type dominates the platform's catalog.
#
# The distribution provides an overview of Amazon Prime's content strategy and serves as a baseline for further analysis of genres, ratings, and release trends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights can help Amazon Prime Video optimize its content acquisition and production strategy. Understanding whether the platform is heavily focused on movies or TV shows enables decision-makers to balance the content library according to audience demand, improve user satisfaction, and strengthen subscriber engagement.
#
# Negative Growth Insight (if applicable):
#
# If the platform's catalog is heavily skewed toward one content type (for example, significantly more movies than TV shows), it may indicate limited variety for users who prefer long-form series. Such an imbalance could reduce viewer retention and engagement among certain audience segments. Maintaining a balanced and diverse content library can help attract a broader audience and improve customer satisfaction.

# %% [markdown]
# #### Chart - 2

# %%
# Chart 2: Content Released Over the Years

plt.figure(figsize=(14,6))

titles_df['release_year'].value_counts().sort_index().plot(
    kind='line',
        marker='o',
            linewidth=2,
                color='teal')
plt.title('Content Released Over the Years', fontsize=16)
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was selected because the variable release_year represents a chronological sequence, making it ideal for analyzing changes over time. Unlike bar charts or pie charts, a line chart effectively illustrates trends, patterns, and fluctuations in the number of titles released each year. It enables us to identify periods of rapid growth, stagnation, or decline in Amazon Prime Video's content library. Since one of the primary objectives of Exploratory Data Analysis (EDA) is to understand how the platform's content has evolved over time, a line chart provides the clearest and most meaningful representation of this time-series data. It also allows stakeholders to easily interpret long-term content expansion and identify years with significant changes in production or acquisition.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the yearly trend in the number of movies and TV shows available on Amazon Prime Video. It shows how the platform's content library has evolved over time and highlights periods of increased or decreased content additions.
#
# Key insights include:
#
# - There is an overall upward trend in content releases, indicating continuous expansion of Amazon Prime's catalog.
# - Recent years generally exhibit a higher number of releases compared to earlier years, suggesting increased investment in both original productions and licensed content.
#
# - Certain years may show sudden spikes, reflecting aggressive content acquisition strategies or increased production activities.
#
# - Any noticeable decline or fluctuation in specific years may indicate external factors such as production delays, licensing changes, or global events affecting the entertainment industry.
#
# - The chart demonstrates Amazon Prime's commitment to consistently expanding its content offerings to attract and retain subscribers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights obtained from this chart can significantly support business decision-making and strategic planning.
#
# Positive business impacts include:
#
# - Helps management evaluate whether the platform is maintaining consistent content growth.
#
# - Supports future content acquisition and production planning based on historical trends.
# - Assists in forecasting content demand and allocating budgets more effectively.
# - Enables Amazon Prime to identify successful expansion periods and replicate effective strategies.
# - Helps marketing teams plan promotional campaigns during periods of high content releases.
# - Contributes to improving customer satisfaction by ensuring a continuous flow of fresh content.
# - Strengthens Amazon Prime's competitive position by monitoring long-term content growth relative to industry trends.
#
# Negative Growth Insight (if applicable)
#
# If the chart shows a decline in the number of titles released during certain years, it may indicate reduced investment in content production or acquisition, licensing challenges, or disruptions caused by external events such as the COVID-19 pandemic. A prolonged decrease in new content could negatively affect subscriber engagement, increase customer churn, and reduce the platform's competitiveness against other streaming services that regularly introduce fresh content. Therefore, maintaining a steady and balanced release schedule is essential for sustaining viewer interest, improving customer retention, and supporting long-term business growth.

# %% [markdown]
# #### Chart - 3

# %%
# Chart 3: Top 10 Most Popular Genres

from collections import Counter

# Split genres and count their frequency
genre_list = titles_df['genres'].dropna().astype(str)

all_genres = []
for genres in genre_list:
    genres = genres.strip("[]").replace("'", "").split(", ")
    all_genres.extend(genres)

genre_count = Counter(all_genres)

genre_df = pd.DataFrame(
    genre_count.items(),
    columns=['Genre', 'Count']
).sort_values(by='Count', ascending=False).head(10)

# Plot
plt.figure(figsize=(12,6))
sns.barplot(data=genre_df, x='Count', y='Genre', palette='viridis')

plt.title('Top 10 Most Popular Genres on Amazon Prime', fontsize=16)
plt.xlabel('Number of Titles')
plt.ylabel('Genre')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was selected because it is the most effective visualization for comparing the frequency of multiple categorical variables such as genres. Since the dataset contains numerous genres with varying title counts, a horizontal bar chart makes it easier to compare values, rank genres from highest to lowest, and display long genre names without overlapping. This chart clearly highlights the most common genres available on Amazon Prime Video and enables quick identification of content preferences within the platform's catalog.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides a clear ranking of the ten most common genres available on Amazon Prime Video.
# Key insights include:
#
# - Certain genres dominate the platform's catalog, indicating higher investment in those categories.
# - Popular genres such as Drama, Comedy, Action, Documentary, and Thriller (depending on your dataset output) contribute a significant portion of the total content library.
# - The presence of multiple high-performing genres suggests that Amazon Prime caters to diverse audience preferences rather than focusing on a single category.
# - Lower-ranked genres among the top ten indicate niche markets that may have comparatively smaller audiences but still contribute to overall catalog diversity.
# - The chart helps identify content categories that receive greater production and licensing investments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights from this chart can directly support strategic business decisions.
#
# Positive business impacts include:
#
# - Helps Amazon Prime understand which genres attract the largest audience.
# - Assists content acquisition teams in purchasing titles from high-demand genres.
# Supports investment decisions for producing Amazon - Originals in popular categories.
# - Enables personalized recommendation systems by emphasizing viewer-preferred genres.
# - Helps marketing teams design genre-specific promotional campaigns to improve customer engagement.
# - Encourages data-driven decision-making that maximizes viewer satisfaction and subscriber retention.
#
# Negative Growth Insight (if applicable):
#
# If the chart reveals that only a few genres dominate the platform while several others have very limited representation, it may indicate an imbalance in the content library. Overdependence on a small number of genres can reduce content diversity, making the platform less attractive to viewers with different interests. This may result in lower engagement from niche audience segments, decreased watch time, and potential subscriber loss to competing streaming platforms offering a broader variety of content. Therefore, Amazon Prime should maintain a balanced content portfolio by investing in both popular and emerging genres to ensure sustainable long-term growth.

# %% [markdown]
# #### Chart - 4

# %%
# Chart 4: Distribution of IMDb Ratings

plt.figure(figsize=(10,6))

sns.histplot(
    titles_df['imdb_score'].dropna(),
    bins=20,
    kde=True,
    color='royalblue'
)

plt.title('Distribution of IMDb Ratings', fontsize=16)
plt.xlabel('IMDb Rating')
plt.ylabel('Number of Titles')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with a Kernel Density Estimate (KDE) was chosen because IMDb score is a continuous numerical variable. Histograms are the most suitable visualization for understanding the distribution of numerical data, while the KDE curve provides a smoother representation of the distribution pattern. This chart helps identify where most Amazon Prime titles are concentrated in terms of ratings, whether the data is normally distributed or skewed, and whether there are any unusually high or low-rated titles.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides valuable insights into the quality distribution of Amazon Prime content.
#
# Key insights include:
#
# - Most titles are concentrated within the mid-to-high IMDb rating range, indicating that a large proportion of Amazon Prime's catalog is reasonably well received by audiences.
# - Very low-rated and exceptionally high-rated titles are comparatively fewer, suggesting that the platform maintains a balanced quality standard.
# - The distribution helps identify the average quality level of content available on the platform.
# - Any skewness in the distribution indicates whether Amazon Prime contains more highly rated content or more average-rated titles.
# - The presence of outliers highlights exceptionally successful or poorly received titles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Chart 5: Top 10 Production Countries

from collections import Counter

country_list = titles_df['production_countries'].dropna().astype(str)

all_countries = []

for countries in country_list:
    countries = countries.strip("[]").replace("'", "").split(", ")
    all_countries.extend(countries)

country_count = Counter(all_countries)

country_df = pd.DataFrame(
    country_count.items(),
    columns=['Country', 'Count']
).sort_values(by='Count', ascending=False).head(10)

# Plot
plt.figure(figsize=(12,6))

sns.barplot(
    data=country_df,
    x='Count',
    y='Country',
    palette='magma'
)

plt.title('Top 10 Production Countries on Amazon Prime', fontsize=16)
plt.xlabel('Number of Titles')
plt.ylabel('Production Country')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because production country is a categorical variable with multiple unique values. This chart provides an effective way to compare the number of titles produced by different countries and rank them from highest to lowest. Horizontal bars also improve readability when country names are long. Displaying only the top 10 countries keeps the visualization clear and highlights the major contributors to Amazon Prime's content library.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides insights into the geographical distribution of Amazon Prime's content.
#
# Key insights include:
#
# - A small number of countries contribute the majority of titles available on Amazon Prime.
# - Countries such as the United States, India, the United Kingdom, Canada, and Japan (depending on your dataset) are likely to dominate the content library.
# - The distribution indicates Amazon Prime's strongest production and licensing markets.
# - The presence of titles from multiple countries demonstrates the platform's international content strategy and global audience reach.
# - Countries with fewer titles represent opportunities for future regional content expansion.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights can support strategic decisions related to content acquisition and global market expansion.
#
# Positive business impacts include:
#
# - Helps Amazon Prime identify its strongest content-producing regions.
# - Supports regional investment decisions for original content production.
# - Enables expansion into emerging markets with growing streaming audiences.
# - Assists localization strategies by identifying countries requiring more region-specific content.
# - Improves customer satisfaction by maintaining a diverse international content catalog.
#
# Negative Growth Insight (if applicable)
#
# If the chart shows that most titles originate from only one or two countries, it may indicate limited geographical diversity in the content library. Such concentration can reduce the platform's appeal to international audiences who prefer local-language or region-specific content. This may limit subscriber growth in emerging markets and provide competitors with an advantage in regions where localized content is in higher demand. Increasing investments in content from underrepresented countries can improve global reach, user engagement, and long-term business growth.

# %% [markdown]
# #### Chart - 6

# %%
# Chart 6: Top 10 Directors with the Most Titles

# Filter only directors
directors = credits_df[credits_df['role'] == 'DIRECTOR']

# Count titles directed by each director
top_directors = directors['name'].value_counts().head(10)

# Plot
plt.figure(figsize=(12,6))

sns.barplot(
    x=top_directors.values,
    y=top_directors.index,
    palette='coolwarm'
)

plt.title('Top 10 Directors with the Most Titles on Amazon Prime', fontsize=16)
plt.xlabel('Number of Titles')
plt.ylabel('Director')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because the objective is to compare the number of titles directed by different directors. Since director names are categorical and often lengthy, a horizontal bar chart provides better readability than a vertical bar chart. Displaying only the Top 10 directors makes the visualization concise while highlighting the most influential filmmakers contributing to Amazon Prime's content library.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart identifies the directors with the highest number of titles available on Amazon Prime Video.
#
# Key insights include:
#
# - A few directors contribute significantly more titles than others, indicating strong collaboration with Amazon Prime or extensive filmographies.
#
# - The ranking highlights the platform's reliance on experienced and prolific directors.
#
# - The presence of multiple directors with similar title counts suggests a diversified content acquisition strategy rather than dependence on a single filmmaker.
#
# - The chart helps identify directors whose content consistently appears on the platform and may attract loyal audiences.
#
# - It also provides insights into potential partnerships and production trends within the streaming industry.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights obtained from this chart can help Amazon Prime improve both its content strategy and business performance.
#
# Positive business impacts include:
#
# - Identifies directors whose titles perform well and resonate with audiences.
#
# - Supports strategic partnerships with successful directors for future Amazon Originals.
#
# - Helps the content acquisition team prioritize licensing from directors with strong viewer appeal.
#
# - Assists marketing teams in promoting collections featuring well-known filmmakers.
#
# - Enhances recommendation systems by suggesting titles from directors preferred by viewers, thereby increasing watch time and subscriber engagement.
#
# Negative Growth Insight (if applicable)
#
# If the chart reveals that a large proportion of titles are concentrated among only a few directors, it may indicate limited creative diversity in the platform's content library. Excessive reliance on a small group of filmmakers could reduce content variety, making the catalog less appealing to audiences seeking fresh storytelling styles and diverse perspectives. Expanding collaborations with emerging and international directors can strengthen content diversity, attract new audience segments, and support long-term subscriber growth.

# %% [markdown]
# #### Chart - 7

# %%
# Chart 7: Top 10 Actors with the Most Titles

# Filter only actors
actors = credits_df[credits_df['role'] == 'ACTOR']

# Count appearances of each actor
top_actors = actors['name'].value_counts().head(10)

# Plot
plt.figure(figsize=(12,6))

sns.barplot(
    x=top_actors.values,
    y=top_actors.index,
    palette='crest'
)

plt.title('Top 10 Actors with the Most Titles on Amazon Prime', fontsize=16)
plt.xlabel('Number of Titles')
plt.ylabel('Actor')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was selected because it is the most effective way to compare categorical data such as actor names. Since there are thousands of actors in the dataset, displaying only the Top 10 actors with the highest number of titles provides a clear and meaningful comparison. The horizontal orientation improves readability, especially for long actor names, and allows viewers to quickly identify the most frequently appearing actors on Amazon Prime Video.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the actors who have the highest number of movies and TV shows available on Amazon Prime Video.
#
# Key insights include:
#
# - A small group of actors appears in a significantly larger number of titles than others.
#
# - These actors have a strong presence on the platform, indicating either long acting careers or extensive licensing of their work.
#
# - The distribution reflects Amazon Prime's collaboration with well-established actors whose content is likely to attract viewers.
#
# - The chart also demonstrates the diversity of the platform's catalog by showcasing actors from different industries and regions.
#
# - Identifying frequently featured actors can help understand audience preferences and content acquisition strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights obtained from this chart can support several strategic business decisions.
#
# Positive business impacts include:
#
# - Helps Amazon Prime identify actors whose content attracts higher audience engagement.
#
# - Supports future licensing and production decisions involving popular actors.
#
# - Enables marketing teams to create actor-based promotional campaigns and curated collections.
#
# - Improves recommendation systems by suggesting titles featuring viewers' favorite actors.
#
# - Assists in increasing watch time, customer satisfaction, and subscriber retention through personalized content recommendations.
#
# Negative Growth Insight (if applicable)
#
# If the chart indicates that the majority of titles are concentrated among only a few actors, it may suggest limited diversity in the featured cast. Overreliance on a small number of actors can reduce content variety and may not appeal to audiences seeking fresh talent or regional representation. This could affect viewer engagement and subscriber growth over time. To maintain long-term competitiveness, Amazon Prime should continue expanding its catalog with content featuring diverse and emerging actors from different countries and film industries.

# %% [markdown]
# #### Chart - 8

# %%
# Chart 8: Distribution of Movie Runtime

# Filter only movies
movies = titles_df[titles_df['type'] == 'MOVIE']

plt.figure(figsize=(10,6))

sns.histplot(
    movies['runtime'].dropna(),
    bins=30,
    kde=True,
    color='darkorange'
)

plt.title('Distribution of Movie Runtime', fontsize=16)
plt.xlabel('Runtime (Minutes)')
plt.ylabel('Number of Movies')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with a Kernel Density Estimate (KDE) was selected because runtime is a continuous numerical variable. Histograms are ideal for understanding the distribution of numerical data by showing how movie durations are spread across different runtime intervals. The KDE curve provides a smooth representation of the overall distribution, making it easier to identify common runtime ranges, skewness, and potential outliers. This visualization helps determine the typical duration of movies available on Amazon Prime Video.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides valuable insights into the duration of movies available on Amazon Prime Video.
#
# Key insights include:
#
# - Most movies are concentrated within a specific runtime range, indicating the standard duration preferred by filmmakers and audiences.
#
# - Extremely short and extremely long movies are relatively uncommon, suggesting that the majority of content follows conventional movie lengths.
#
# - The distribution helps identify the average runtime of movies available on the platform.
#
# - Any outliers represent unusually long or short films that cater to specific audience preferences or unique storytelling formats.
#
# - Understanding runtime distribution provides insights into the overall structure of Amazon Prime's movie catalog.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights gained from this chart can help Amazon Prime improve its content strategy and user experience.
#
# Positive business impacts include:
#
# - Helps understand the movie duration preferred by viewers.
#
# - Supports content acquisition decisions by identifying the most common and successful runtime range.
#
# - Enables recommendation systems to suggest movies based on users' available viewing time.
#
# - Assists content producers in designing movies that align with audience preferences.
#
# - Improves customer satisfaction by offering a balanced catalog of short, medium, and long-duration films.
#
# Negative Growth Insight (if applicable)
#
# If the chart reveals that a large proportion of movies have unusually long runtimes, some viewers may be discouraged from watching them due to time constraints, resulting in lower completion rates and reduced engagement. Conversely, an overabundance of very short movies may fail to meet audience expectations for feature-length entertainment. Maintaining a balanced mix of movie durations can help maximize viewer satisfaction, increase watch time, and support long-term subscriber retention.

# %% [markdown]
# #### Chart - 9

# %%
# Chart 9: IMDb Votes vs IMDb Rating

plt.figure(figsize=(10,6))

sns.scatterplot(
    data=titles_df,
    x='imdb_votes',
    y='imdb_score',
    alpha=0.6,
    color='purple'
)

plt.title('IMDb Votes vs IMDb Rating', fontsize=16)
plt.xlabel('IMDb Votes')
plt.ylabel('IMDb Rating')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was selected because it is the most appropriate visualization for examining the relationship between two continuous numerical variables: IMDb Votes and IMDb Score. Unlike bar charts or histograms, a scatter plot allows us to identify correlations, clusters, trends, and outliers within the data. It helps determine whether titles with a larger number of audience votes generally receive higher ratings or if there is little relationship between popularity and audience satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot provides valuable insights into audience engagement and content quality.
#
# Key insights include:
#
# - It shows whether titles receiving more IMDb votes also tend to have higher IMDb ratings.
#
# - Highly voted titles often indicate greater audience reach and popularity.
#
# - Clusters of points reveal the rating range where most Amazon Prime titles are concentrated.
#
# - Outliers represent exceptionally popular titles with very high votes or highly rated niche content with relatively few votes.
#
# -The chart helps distinguish between widely popular content and critically appreciated but less-viewed titles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights from this chart can support strategic content and marketing decisions.
#
# Positive business impacts include:
#
# - Helps identify blockbuster titles that combine high ratings with strong audience engagement.
#
# - Supports content acquisition by highlighting characteristics of successful movies and TV shows.
#
# - Enables recommendation systems to prioritize highly rated and highly voted content.
#
# - Assists marketing teams in promoting titles with strong audience approval.
#
# - Improves investment decisions for future original productions based on audience preferences and engagement patterns.
#
# Negative Growth Insight (if applicable)
#
# If the scatter plot shows many titles with high IMDb votes but relatively low ratings, it may indicate that although these titles attract viewers, they fail to meet audience expectations. This can lead to lower customer satisfaction, negative reviews, and reduced subscriber retention. Conversely, if many highly rated titles receive very few votes, it may suggest insufficient promotion or limited visibility. Amazon Prime can address these issues by improving content quality, enhancing recommendation algorithms, and increasing marketing efforts for critically acclaimed but underexposed titles.

# %% [markdown]
# #### Chart - 10

# %%
# Chart 10: Top 10 Highest Rated Movies on Amazon Prime

# Filter movies with IMDb scores
top_movies = (
    titles_df[titles_df['type'] == 'MOVIE']
    .sort_values(by='imdb_score', ascending=False)
    .drop_duplicates(subset='title')
    .head(10)
)

# Plot
plt.figure(figsize=(12,6))

sns.barplot(
    data=top_movies,
    x='imdb_score',
    y='title',
    palette='Blues_r'
)

plt.title('Top 10 Highest Rated Movies on Amazon Prime', fontsize=16)
plt.xlabel('IMDb Rating')
plt.ylabel('Movie Title')

plt.xlim(0, 10)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it is the most effective way to compare IMDb ratings across multiple movie titles. Since movie titles are categorical variables and can be relatively long, a horizontal layout improves readability and makes it easy to rank movies from the highest to the lowest rating. Displaying the Top 10 highest-rated movies provides a concise yet informative overview of the best-performing content available on Amazon Prime Video.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the movies with the highest IMDb ratings available on Amazon Prime Video.
#
# Key insights include:
#
# - The top-rated movies consistently receive exceptionally high IMDb scores, reflecting strong audience appreciation.
#
# - These movies represent high-quality content that can significantly enhance the platform's reputation.
#
# - The chart helps identify the types of movies that resonate most with viewers and achieve critical success.
#
# - Highly rated movies can serve as benchmark content for future acquisitions and original productions.
#
# - The ranking also showcases Amazon Prime's ability to provide premium-quality entertainment across different genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights from this chart can directly support strategic business decisions.
#
# Positive business impacts include:
#
# - Helps Amazon Prime identify and promote its highest-quality content.
#
# - Supports recommendation systems by prioritizing critically acclaimed movies.
#
# - Assists content acquisition teams in selecting movies with characteristics similar to highly rated titles.
#
# - Enables marketing teams to feature top-rated movies in campaigns, increasing viewer engagement and watch time.
#
# - Strengthens customer satisfaction and subscriber retention by highlighting premium content.
#
# Negative Growth Insight (if applicable)
#
# If only a small number of movies achieve exceptionally high ratings while the majority of the catalog receives average or below-average ratings, it may indicate inconsistency in overall content quality. Such inconsistency can reduce viewer satisfaction and encourage subscribers to explore competing streaming platforms that offer a larger selection of highly rated content. To ensure sustainable growth, Amazon Prime should continue investing in high-quality productions and regularly evaluate lower-performing titles to improve the overall standard of its content library.

# %% [markdown]
# #### Chart - 11

# %%
# Chart 11: Top 10 Most Popular Titles (TMDb Popularity)

top_popular = (
    titles_df[['title', 'tmdb_popularity']]
    .dropna()
    .sort_values(by='tmdb_popularity', ascending=False)
    .head(10)
)

# Plot
plt.figure(figsize=(12,6))

sns.barplot(
    data=top_popular,
    x='tmdb_popularity',
    y='title',
    palette='rocket'
)

plt.title('Top 10 Most Popular Titles on Amazon Prime (TMDb Popularity)', fontsize=16)
plt.xlabel('TMDb Popularity Score')
plt.ylabel('Title')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it is the most suitable visualization for comparing the popularity scores of different titles. The TMDb popularity score is a numerical metric that reflects how popular a movie or TV show is based on user engagement and interest. Since movie and TV show titles are categorical variables with varying name lengths, a horizontal bar chart provides better readability and allows the titles to be ranked clearly from the most popular to the least popular. Displaying the Top 10 titles ensures that the visualization remains focused and easy to interpret.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides valuable insights into the most popular content available on Amazon Prime Video.
#
# Key insights include:
#
# - The top-ranked titles have significantly higher TMDb popularity scores than the remaining content, indicating strong audience interest.
#
# - Popular titles are likely to generate higher viewership, increased engagement, and greater visibility on the platform.
#
# - The popularity distribution helps identify blockbuster movies and trending TV shows that attract the largest audience.
#
# - These highly popular titles can serve as flagship content for Amazon Prime and contribute substantially to subscriber acquisition and retention.
#
# - The chart also highlights the importance of investing in content that resonates with global audiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights from this chart can directly support strategic business decisions and improve platform performance.
#
# Positive business impacts include:
#
# - Helps Amazon Prime identify its most attractive and high-performing content.
#
# - Supports recommendation systems by prioritizing trending titles for users.
#
# - Assists marketing teams in promoting the platform's most popular movies and TV shows.
#
# - Enables content acquisition teams to identify characteristics of highly popular titles for future investments.
#
# - Improves user engagement, watch time, customer satisfaction, and subscriber retention by highlighting content with proven audience appeal.
#
# Negative Growth Insight (if applicable)
#
# If the chart reveals that only a few titles account for most of the platform's popularity while the majority of content has relatively low popularity scores, it may indicate an imbalance in audience engagement. Overdependence on a limited number of blockbuster titles can reduce the visibility of other quality content and increase business risk if viewer interest shifts. Amazon Prime can address this challenge by improving personalized recommendations, promoting lesser-known high-quality titles, and investing in a broader range of engaging content to maintain long-term subscriber growth and platform competitiveness.

# %% [markdown]
# #### Chart - 12

# %%
# Chart 12: Distribution of Age Certifications

plt.figure(figsize=(10,6))

age_cert = (
    titles_df['age_certification']
    .fillna('Not Rated')
    .value_counts()
)

sns.barplot(
    x=age_cert.index,
    y=age_cert.values,
    palette='Set3'
)

plt.title('Distribution of Age Certifications on Amazon Prime', fontsize=16)
plt.xlabel('Age Certification')
plt.ylabel('Number of Titles')

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected because Age Certification is a categorical variable consisting of different content ratings such as PG, PG-13, R, TV-MA, TV-14, G, and others. A bar chart is the most effective way to compare the number of titles in each certification category. It provides a clear visual ranking of the content distribution across age groups and helps identify the primary audience targeted by Amazon Prime Video. This visualization is simple to interpret and is highly effective for comparing multiple discrete categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart provides valuable insights into the target audience of Amazon Prime's content library.
#
# Key insights include:
#
# - The majority of titles belong to a few dominant age certification categories, indicating Amazon Prime's primary target audience.
#
# - A higher number of adult-oriented certifications (such as TV-MA or R, depending on your dataset) suggests that the platform focuses heavily on mature audiences.
#
# - The presence of family-friendly certifications such as G, PG, and TV-Y demonstrates that Amazon Prime also caters to children and family viewers.
#
# - Titles with Not Rated certifications indicate incomplete metadata or content that has not received an official certification.
#
# - The distribution helps understand how diversified the platform is across different audience age groups.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights from this chart can significantly support business and content strategy.
#
# Positive business impacts include:
#
# - Helps Amazon Prime understand whether its catalog effectively serves children, families, teenagers, and adult audiences.
#
# - Supports content acquisition by identifying underrepresented audience segments.
#
# - Enables personalized recommendations based on viewer age preferences.
#
# - Assists parental control and content filtering features.
#
# - Helps marketing teams design age-specific promotional campaigns, increasing customer satisfaction and viewer engagement.
#
# - Supports strategic investments in family-friendly or mature content based on demand.
#
# Negative Growth Insight (if applicable)
#
# If the chart shows that the majority of content is concentrated within only one or two age certification categories, it may indicate an imbalance in the content library. For example, an excessive focus on mature content could reduce the platform's appeal to families and younger audiences, while too much children's content might limit engagement among adult viewers. Such an imbalance can restrict market reach and subscriber growth. Maintaining a well-balanced catalog across different age groups can help Amazon Prime attract a wider audience, improve user satisfaction, and strengthen long-term business growth.

# %% [markdown]
# #### Chart - 13

# %%
# Chart 13: Top 10 Highest Rated TV Shows on Amazon Prime

# Filter TV Shows with IMDb scores
top_tv_shows = (
    titles_df[titles_df['type'] == 'SHOW']
    .sort_values(by='imdb_score', ascending=False)
    .drop_duplicates(subset='title')
    .head(10)
)

# Plot
plt.figure(figsize=(12,6))

sns.barplot(
    data=top_tv_shows,
    x='imdb_score',
    y='title',
    palette='Greens_r'
)

plt.title('Top 10 Highest Rated TV Shows on Amazon Prime', fontsize=16)
plt.xlabel('IMDb Rating')
plt.ylabel('TV Show Title')

plt.xlim(0, 10)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it is the most effective visualization for comparing IMDb ratings across multiple TV shows. TV show titles are categorical variables, and a horizontal layout makes long titles easier to read while clearly ranking them from the highest-rated to the lowest-rated. Displaying only the Top 10 highest-rated TV shows keeps the chart clean, focused, and easy to interpret. This visualization helps identify the best-performing series on Amazon Prime and provides valuable insights into audience preferences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights the TV shows with the highest IMDb ratings available on Amazon Prime Video.
#
# Key insights include:
#
# - The top-ranked TV shows have exceptionally high IMDb ratings, indicating strong audience appreciation and critical acclaim.
#
# - These highly rated series represent premium-quality content that strengthens Amazon Prime's content portfolio.
#
# - The chart helps identify the types of TV shows that consistently receive positive audience feedback.
#
# - Highly rated series are likely to generate greater viewer engagement, longer watch times, and stronger subscriber retention.
#
# - The ranking can serve as a benchmark for future content acquisition and original series production.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The insights from this chart can significantly improve business strategy and customer engagement.
#
# Positive business impacts include:
#
# - Helps Amazon Prime identify and promote its highest-performing TV shows.
#
# - Supports recommendation engines by prioritizing critically acclaimed series.
#
# - Assists content acquisition teams in investing in similar high-quality TV shows.
#
# - Enables marketing teams to highlight top-rated series in promotional campaigns, increasing viewership.
#
# - Improves customer satisfaction, binge-watching behavior, and subscriber retention through better content recommendations.
#
# - Supports strategic investments in original series that align with audience preferences.
#
# Negative Growth Insight (if applicable)
#
# If only a few TV shows achieve very high IMDb ratings while the majority receive average or low ratings, it may indicate inconsistency in the overall quality of the platform's television content. This could reduce viewer satisfaction, discourage long-term engagement, and increase the likelihood of subscribers switching to competing streaming services with a stronger collection of highly rated series. To address this, Amazon Prime should continue investing in high-quality original productions, monitor audience feedback, and expand its catalog with critically acclaimed TV shows to maintain long-term competitiveness and subscriber growth.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code


plt.figure(figsize=(10,8))

# Select numerical columns
numeric_df = titles_df.select_dtypes(include=['int64', 'float64'])

# Correlation matrix
corr_matrix = numeric_df.corr()

# Plot heatmap
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt='.2f',
    linewidths=0.5
)

plt.title('Correlation Heatmap of Numerical Variables', fontsize=16)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Correlation Heatmap was selected because it is one of the most effective visualizations for understanding the relationships between multiple numerical variables simultaneously. Unlike individual scatter plots that compare only two variables at a time, a heatmap summarizes the correlation between every pair of numerical features in a single figure. It uses color intensity to indicate the strength and direction of the relationship, making it easy to identify strong positive, strong negative, and weak correlations. This visualization is particularly useful during Exploratory Data Analysis (EDA) because it helps detect patterns, identify redundant variables, and discover important relationships that may influence business decisions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heatmap provides several valuable insights into the numerical variables present in the Amazon Prime dataset.
#
# Key insights include:
#
# - Variables with correlation values close to +1 have a strong positive relationship, meaning they tend to increase together.
#
# - Variables with correlation values close to -1 have a strong negative relationship, indicating that as one variable increases, the other decreases.
#
# - Correlation values near 0 suggest little or no linear relationship between the variables.
#
# - IMDb Score and TMDb Score often show a moderate to strong positive correlation, indicating that highly rated titles on one platform are generally rated well on the other.
#
# - IMDb Votes may show a positive relationship with TMDb Popularity, suggesting that widely viewed titles tend to receive more audience attention across platforms.
#
# - Runtime, release year, and popularity generally exhibit weaker correlations, indicating that these variables influence content performance independently.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code


# Select important numerical columns
pairplot_df = titles_df[
    ['release_year', 'runtime', 'imdb_score',
     'imdb_votes', 'tmdb_score', 'tmdb_popularity']
].dropna()

# Create Pair Plot
sns.pairplot(
    pairplot_df,
    diag_kind='kde',
    corner=True
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Pair Plot was selected because it is one of the most comprehensive visualizations for Exploratory Data Analysis (EDA). Unlike individual charts that analyze only one or two variables, a pair plot simultaneously displays the relationships among multiple numerical variables in the dataset. It combines scatter plots for every pair of variables and distribution plots along the diagonal, allowing us to observe trends, correlations, clusters, and potential outliers in a single visualization. This makes it an excellent tool for understanding the overall structure of the data before performing deeper analysis or predictive modeling.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot provides a detailed overview of the relationships between numerical variables such as Release Year, Runtime, IMDb Score, IMDb Votes, TMDb Score, and TMDb Popularity.
#
# Key insights include:
#
# - The diagonal plots show the distribution of each numerical variable, helping identify skewness, spread, and outliers.
#
# - Scatter plots reveal the relationships between different variables and indicate whether they have positive, negative, or weak correlations.
#
# - IMDb Score and TMDb Score often display a positive relationship, suggesting that titles highly rated on one platform are generally well-rated on the other.
#
# - IMDb Votes and TMDb Popularity may show a positive association, indicating that popular titles tend to receive greater audience engagement.
#
# - Runtime generally exhibits a weak relationship with ratings, implying that longer movies or shows are not necessarily rated higher.
#
# - The visualization also helps identify clusters of similar titles and unusual observations that may require further investigation.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the Exploratory Data Analysis (EDA) of the Amazon Prime TV Shows and Movies dataset, the following recommendations can help Amazon Prime Video achieve its business objectives of increasing subscriber growth, improving customer satisfaction, enhancing user engagement, and strengthening its competitive position in the streaming industry.
#
# 1. Invest More in High-Rated Content:
# The analysis shows that highly rated movies and TV shows contribute significantly to viewer satisfaction. Amazon Prime should prioritize acquiring and producing content that consistently receives strong audience ratings and positive reviews.
#
# 2. Expand Successful Genres: The platform should continue investing in genres that have the highest number of titles and strong audience demand while also introducing fresh content in emerging genres. Maintaining a balanced genre portfolio will attract a wider audience and increase watch time.
#
# 3. Strengthen Regional and International Content: Since content originates from multiple countries, Amazon Prime should expand its investment in regional and local-language productions. This strategy will help attract subscribers from emerging markets and improve global customer engagement.
#
# 4. Collaborate with Successful Directors and Actors: The analysis identified directors and actors with a strong presence in the catalog. Partnering with well-known filmmakers and talented actors for exclusive content can increase platform popularity and improve subscriber acquisition.
#
# 5. Improve Recommendation Systems: Using factors such as IMDb ratings, TMDb popularity, genres, actors, directors, and viewing behavior, Amazon Prime can deliver more personalized recommendations. Better recommendations increase viewer satisfaction, watch time, and customer retention.
#
# 6. Maintain a Balanced Content Library: The platform should ensure a healthy balance between Movies and TV Shows, different genres, and various age certifications. A diverse content catalog appeals to audiences of all age groups and reduces the risk of losing subscribers due to limited content variety.
#
# 7. Promote High-Quality but Less Popular Titles: Some highly rated titles may receive relatively low audience attention. Amazon Prime should improve promotional campaigns and recommendation algorithms to increase the visibility of these hidden gems, maximizing the value of its existing content library.
#
# 8. Use Data-Driven Decision Making: Amazon Prime should continuously monitor audience ratings, popularity scores, viewing trends, and content performance to guide future content acquisition and production decisions. Leveraging data analytics will reduce investment risks and improve overall business performance.
#
# Overall Recommendation
#
# By focusing on high-quality content, expanding regional productions, maintaining a diverse content library, strengthening personalization, and making data-driven decisions, Amazon Prime Video can improve customer satisfaction, increase viewer engagement, enhance subscriber retention, and achieve sustainable long-term business growth while maintaining a strong competitive advantage in the global streaming industry.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The Exploratory Data Analysis (EDA) of the Amazon Prime TV Shows and Movies dataset provided valuable insights into the platform's content library, audience preferences, and content distribution. The analysis revealed that Amazon Prime offers a diverse collection of movies and TV shows across multiple genres, countries, age certifications, and production years, reflecting its strong global presence in the streaming industry.
#
# The visualizations showed that certain genres, directors, actors, and production countries contribute significantly to the platform's catalog. The analysis of IMDb ratings, TMDb scores, popularity, and audience votes indicated that high-quality content generally attracts greater audience engagement, although popularity and ratings do not always move together. This highlights the importance of maintaining both content quality and effective promotion.
#
# Further analysis of runtime, release trends, age certifications, correlation heatmaps, and pair plots provided a deeper understanding of the relationships among different variables. The findings suggest that Amazon Prime should adopt a balanced content strategy by investing in highly rated titles, expanding regional and multilingual content, maintaining diversity across genres and age groups, and leveraging data-driven insights for future content acquisition and production decisions.
#
# Overall, this EDA demonstrates how data analytics can support strategic decision-making in the entertainment industry. By continuously monitoring audience behavior, content performance, and market trends, Amazon Prime can enhance customer satisfaction, improve personalized recommendations, increase viewer engagement, strengthen subscriber retention, and achieve sustainable long-term business growth. The insights generated from this project can serve as a valuable foundation for future predictive analytics, recommendation systems, and business intelligence initiatives.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
