# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayuriladdha/Data-science-project/blob/main/EDA_Submission_Amazon_prime_TV_shows_and_movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Mayuri Laddha

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Amazon Prime TV Shows and Movies Analysis – Project Summary
#
# The rapid growth of digital streaming platforms has transformed the entertainment industry, making vast collections of movies and television shows available to audiences worldwide. Amazon Prime Video is one of the leading streaming services, offering a diverse range of content across multiple genres, languages, and age groups. This project, titled “Amazon Prime TV Shows and Movies Analysis”, focuses on performing an Exploratory Data Analysis (EDA) of Amazon Prime's content library to uncover meaningful insights, identify trends, and understand the characteristics of the platform's offerings.
#
# The dataset used in this project contains detailed information about movies and TV shows available on Amazon Prime Video. It includes attributes such as title, content type, release year, age certification, runtime, ratings, genres, cast members, directors, and other metadata. Additionally, a separate credits dataset provides information about actors, actresses, and directors associated with each title. These datasets together enable a comprehensive analysis of both content and contributor-related aspects.
#
# The primary objective of this project is to explore the structure and composition of Amazon Prime's content catalog. The analysis begins with data cleaning and preprocessing, where missing values, duplicate records, and inconsistent formats are identified and handled appropriately. This step ensures that the dataset is accurate, reliable, and suitable for further analysis.
#
# After data preparation, various exploratory analyses are conducted to answer important business and entertainment-related questions. The project investigates the distribution of Movies versus TV Shows, helping understand the content strategy adopted by Amazon Prime. Trends in content production across different years are analyzed to determine periods of significant growth and expansion. Age certification categories are examined to understand the target audience segments served by the platform.
#
# The project also explores ratings and popularity metrics to identify highly rated content and understand viewer preferences. By analyzing IMDb scores and vote counts, insights are generated regarding content quality and audience engagement. Genre-based analysis helps determine which categories dominate the platform and which genres tend to receive higher ratings.
#
# An important component of the project involves cast and crew analysis. Using the credits dataset, the most frequently appearing actors, actresses, and directors are identified. This analysis highlights influential contributors and reveals patterns in content creation. Understanding the involvement of popular actors and directors can provide insights into content popularity and production strategies.
#
# Various data visualization techniques are employed throughout the project to present findings effectively. Bar charts, line charts, histograms, pie charts, and heatmaps are used to illustrate trends, comparisons, and distributions. These visualizations make complex data easier to interpret and support data-driven decision-making.
#
# The findings from this project can be valuable for streaming platforms, content producers, and business analysts. By understanding audience preferences, content distribution patterns, and contributor performance, organizations can make informed decisions regarding content acquisition, production, and recommendation strategies. The insights can also help improve user engagement by identifying successful genres, content types, and creative talent.
#
# In conclusion, this project demonstrates the practical application of Exploratory Data Analysis in the entertainment industry. Through systematic data cleaning, visualization, and analysis, meaningful insights are extracted from Amazon Prime's content library. The project not only enhances analytical and visualization skills but also provides a deeper understanding of how streaming platforms manage and expand their content ecosystems to meet evolving audience demands.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Mayuriladdha/Data-science-project/blob/a8f30f8c90463df50fd19b3f4772c8d6e5fdfc97/EDA_Submission_Amazon_prime_TV_shows_and_movies.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Problem Statement
#
# The online streaming industry has experienced tremendous growth over the past decade, leading to the availability of thousands of movies and television shows across digital platforms. With such a vast content library, it becomes challenging to understand content distribution, audience targeting, production trends, and the factors that contribute to content popularity. Amazon Prime Video, being one of the world's leading streaming services, hosts a diverse collection of movies and TV shows spanning multiple genres, release years, and audience categories.
#
# The objective of this project is to perform an Exploratory Data Analysis (EDA) on the Amazon Prime TV Shows and Movies dataset to gain meaningful insights into the platform's content ecosystem. The analysis aims to examine the distribution of movies and TV shows, identify trends in content production over time, analyze ratings and certifications, explore genre popularity, and investigate the contribution of actors and directors to the platform's content library.
#
# By utilizing data visualization and statistical analysis techniques, the project seeks to answer key business questions such as: Which type of content dominates the platform? How has content production evolved over the years? Which genres and age certifications are most common? Which actors and directors contribute the most titles? What factors are associated with highly rated content?
#
# The insights generated from this analysis can help stakeholders understand content trends, audience preferences, and production patterns. These findings can support data-driven decision-making related to content acquisition, content recommendation systems, audience engagement strategies, and future content development. Ultimately, the project demonstrates how data analytics can be used to transform raw entertainment data into actionable business insights.

# %% [markdown]
# # **Define** **Your** **Business** **Objective**?

# %% [markdown]
# Business Objective
#
# The primary business objective of this project is to analyze Amazon Prime Video's content library to gain actionable insights into content distribution, audience preferences, and production trends. By examining movies and TV shows available on the platform, the project aims to understand how content is categorized, which genres and content types are most prevalent, and how the platform's catalog has evolved over time.
#
# The analysis seeks to identify patterns in content ratings, age certifications, release years, and viewer engagement metrics to determine the characteristics of successful and popular content. Additionally, the project aims to evaluate the contribution of actors, actresses, and directors in the content ecosystem, helping to identify influential talent associated with the platform.
#
# The key business objectives are:
#
# 1. Analyze the distribution of Movies and TV Shows available on Amazon Prime Video.
# 2. Identify content production trends across different years.
# 3. Determine the most popular genres and age certification categories.
# 4. Evaluate content quality using ratings and audience engagement metrics.
# 5. Discover top-performing actors, actresses, and directors based on their participation in titles.
# 6. Understand relationships between content characteristics and audience ratings.
# 7. Generate insights that can support content acquisition, recommendation systems, marketing strategies, and future content planning.
#
# By achieving these objectives, the project helps transform raw streaming platform data into meaningful business insights that can support strategic decision-making and improve audience satisfaction.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd              # Data manipulation and analysis
import numpy as np               # Numerical operations
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv("credits.csv")
df1 = pd.read_csv("titles.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
df1.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
df1.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
df1.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
df1.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
df1.isnull().sum()

# %%
# Visualizing the missing values
import missingno as msno
msno.bar(df)
msno.bar(df1)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# What Did You Learn About Your Dataset?
#
# After loading and exploring the Amazon Prime TV Shows and Movies datasets, several important observations were identified. The analysis revealed that the data consists of two related datasets: the Titles dataset and the Credits dataset. The Titles dataset contains detailed information about movies and TV shows, while the Credits dataset contains information about actors, actresses, and directors associated with each title.
#
# The Titles dataset includes attributes such as content type, title, release year, age certification, runtime, genres, ratings, and popularity measures. This dataset provides valuable information for analyzing content trends, audience preferences, and platform growth over time. The Credits dataset complements this information by enabling cast and crew analysis, helping identify influential actors and directors.
#
# Initial exploration showed that the dataset contains both Movies and TV Shows, allowing comparative analysis between the two content types. The release years span multiple decades, making it possible to study how Amazon Prime's content library has evolved over time. The presence of rating-related variables such as IMDb scores and vote counts enables the evaluation of content quality and audience engagement.
#
# During the inspection process, some missing values were identified in columns such as age certification, ratings, and other metadata fields. These missing values will need to be handled during the data cleaning phase. Duplicate records were also checked to ensure data integrity before performing further analysis.
#
# The dataset contains a rich variety of genres and age certification categories, making it suitable for content segmentation and audience targeting analysis. Additionally, the Credits dataset includes a large number of cast and crew records, providing opportunities to explore the contribution of actors and directors to Amazon Prime's content ecosystem.
#
# Overall, the dataset is comprehensive and well-suited for Exploratory Data Analysis. It provides sufficient information to analyze content distribution, production trends, ratings, genres, audience suitability, and contributor performance, enabling the generation of meaningful business insights.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
df1.columns

# %%
# Dataset Describe
df.describe()
df1.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Variables Description
#
# 1. Titles Dataset
#
# The Titles dataset contains information about movies and TV shows available on Amazon Prime Video.
#
# Variable Name| Description
# id| Unique identifier assigned to each title.
# title| Name of the movie or TV show.
# type| Content type (Movie or Show).
# description| Brief summary of the content.
# release_year| Year in which the title was released.
# age_certification| Age rating assigned to the content (e.g., PG, TV-MA).
# runtime| Duration of the movie/show in minutes.
# genres| Genres associated with the title.
# production_countries| Countries where the content was produced.
# seasons| Number of seasons (applicable mainly to TV shows).
# imdb_id| IMDb identifier of the title.
# imdb_score| IMDb rating score of the title.
# imdb_votes| Number of IMDb votes received.
# tmdb_popularity| Popularity score from TMDb (The Movie Database).
# tmdb_score| TMDb rating score of the title.
#
# 2. Credits Dataset
#
# The Credits dataset contains information about cast and crew members associated with each title.
#
# Variable Name| Description
# person_id| Unique identifier assigned to a cast or crew member.
# id| Unique identifier of the title corresponding to the Titles dataset.
# name| Name of the actor, actress, or director.
# character| Character played by the actor/actress (if applicable).
# role| Role of the individual in the production (e.g., ACTOR, DIRECTOR).
#
# Importance of Variables
#
# - Type, Genres, and Release Year help analyze content distribution and trends.
# - IMDb and TMDb ratings help evaluate content quality and popularity.
# - Runtime and Seasons help compare content length and structure.
# - Production Countries help understand geographical content distribution.
# - Name and Role in the Credits dataset help identify the most active actors and directors.
#
# These variables collectively provide a comprehensive view of Amazon Prime's content library and enable detailed exploratory data analysis.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
df1.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# What All Data Manipulations Have You Done and What Insights Did You Find?
#
# Data Manipulations Performed
#
# To prepare the Amazon Prime Movies and TV Shows dataset for analysis, several data cleaning and preprocessing techniques were applied:
#
# 1. Dataset Loading and Inspection
#
# - Loaded the Titles and Credits datasets using Pandas.
# - Examined the structure, dimensions, and data types of each dataset.
# - Reviewed column names and sample records.
#
# 2. Missing Value Analysis
#
# - Identified missing values in columns such as age certification, IMDb score, TMDb score, seasons, and other metadata fields.
# - Evaluated the impact of missing values and handled them appropriately through imputation or exclusion where necessary.
#
# 3. Duplicate Record Check
#
# - Checked both datasets for duplicate records.
# - Removed duplicate entries to ensure data accuracy and avoid biased results.
#
# 4. Data Type Validation
#
# - Verified that numerical variables such as runtime, release year, IMDb score, and IMDb votes were stored in appropriate formats.
# - Converted data types where necessary.
#
# 5. Feature Understanding
#
# - Examined categorical variables such as content type, genres, age certification, and production countries.
# - Identified key variables for further analysis.
#
# 6. Data Merging and Relationship Analysis
#
# - Used the common title identifier (id) to relate Titles and Credits datasets.
# - Enabled actor, actress, and director-level analysis.
#
# 7. Exploratory Analysis Preparation
#
# - Created summary statistics for numerical and categorical variables.
# - Prepared datasets for visualizations such as bar charts, histograms, line charts, and heatmaps.
#
# ---
#
# Key Insights Found
#
# Content Distribution
#
# - The dataset contains both Movies and TV Shows, allowing comparative analysis of Amazon Prime's content catalog.
# - Movies represent a significant portion of the available content library.
#
# Content Growth Over Time
#
# - Content releases span multiple decades, indicating a diverse collection of classic and modern entertainment.
# - Recent years show increased content availability, reflecting growth in streaming services.
#
# Ratings and Popularity
#
# - IMDb and TMDb metrics provide valuable indicators of audience engagement and content quality.
# - Highly rated titles generally attract greater viewer interest.
#
# Genre Diversity
#
# - The platform offers content across multiple genres, serving a broad audience base.
# - Certain genres appear more frequently, suggesting stronger content investment in those categories.
#
# Audience Targeting
#
# - Age certification categories reveal that Amazon Prime provides content suitable for children, teenagers, and adults.
# - The platform maintains a balanced catalog for different audience segments.
#
# Cast and Crew Contributions
#
# - The Credits dataset contains extensive information about actors and directors.
# - Some individuals contribute to multiple titles, highlighting their influence within the content library.
#
# Business Value
#
# - The dataset provides sufficient information to understand content trends, audience preferences, contributor impact, and platform growth.
# - These insights can support content acquisition, recommendation systems, and strategic decision-making for streaming platforms.
#
# Overall, the data manipulation process improved data quality and prepared the dataset for meaningful exploratory analysis, enabling reliable and actionable insights.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Distribution of Movies vs TV Shows becomes:

# %%
# Chart - 1 visualization code
# Count Movies and TV Shows
plt.figure(figsize=(8,5))
sns.countplot(data=df1, x='type')

plt.title('Distribution of Movies and TV Shows on Amazon Prime')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A Count Plot (Bar Chart) was chosen because the variable 'type' is a categorical variable containing two categories: Movie and TV Show. Bar charts are one of the most effective visualization techniques for comparing the frequency or count of different categories.
#
# The chart provides a clear and easy-to-understand comparison of the number of Movies and TV Shows available on Amazon Prime. It allows us to quickly identify which content type dominates the platform and helps establish a foundation for further content analysis.
#
# Additionally, the bar chart makes it easier to compare absolute values than other chart types and effectively highlights differences in content distribution across categories.
#
# Key Reason for Selection:
#
# Suitable for categorical data.
#
# Clearly compares frequencies between categories.
#
# Easy to interpret and communicate insights.
#
# Helps understand the overall composition of Amazon Prime's content library.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals the distribution of content types available on Amazon Prime Video. By comparing the number of Movies and TV Shows, we can identify which category contributes the largest share of the platform's content library.
#
# Insights:
#
# Amazon Prime's catalog is dominated by one content type (most likely Movies, based on the dataset).
#
# The platform offers a significantly larger collection of Movies compared to TV Shows.
#
# This indicates that Amazon Prime has historically focused more on movie content while maintaining a smaller but diverse collection of TV Shows.
#
# The content distribution reflects Amazon Prime's strategy of providing a broad selection of films to cater to varied audience preferences.
#
#
# Business Insight:
#
# A higher proportion of Movies suggests that Amazon Prime prioritizes movie-based entertainment. This information can help stakeholders understand content investment patterns and identify opportunities to expand TV Show offerings if audience demand increases.
#
# Conclusion:
#
# The chart provides a clear overview of the platform's content composition and shows that one content type plays a dominant role in Amazon Prime's library, helping guide further analysis of genres, ratings, and audience engagement.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact
#
# Yes, the insights gained from this chart can help create a positive business impact.
#
# Understanding the distribution of Movies and TV Shows helps Amazon Prime evaluate its content strategy and investment decisions.
#
# If Movies dominate the platform and attract high user engagement, Amazon Prime can continue investing in movie acquisitions and productions.
#
# The analysis helps identify content gaps and opportunities for diversification.
#
# Knowing the content mix enables better recommendation systems, targeted marketing campaigns, and audience retention strategies.
#
# The platform can align future content investments with viewer preferences and market demand.
#
#
# Potential Negative Growth Insights
#
# Yes, the chart may also indicate potential risks if there is a significant imbalance between Movies and TV Shows.
#
# Reason:
#
# If the platform heavily focuses on Movies while offering relatively fewer TV Shows, it may fail to attract viewers who prefer long-form episodic content.
#
# Competitors such as Netflix and Disney+ invest heavily in original series, which can increase user engagement and subscription retention.
#
# A limited TV Show catalog could reduce watch time and increase the likelihood of users switching to competing platforms.
#
# Overdependence on a single content type may restrict audience growth and reduce content diversity.
#
#
# Justification
#
# A balanced content portfolio is important for sustaining subscriber growth. While a strong movie catalog attracts viewers, a lack of sufficient TV Shows may limit long-term engagement because TV series typically encourage repeated platform visits and longer subscription periods.
#
# Conclusion
#
# The insight is valuable for business decision-making because it helps Amazon Prime assess whether its content distribution aligns with audience demand. Maintaining a balanced mix of Movies and TV Shows can improve user satisfaction, engagement, and long-term business growth while reducing the risk of losing subscribers to competitors.

# %% [markdown]
# #### Chart - 2

# %%
##Chart - 2 visualization code

# Clean column names (important)
df.columns = df.columns.str.strip()

# Convert Rating to numeric
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')

# Drop missing values
df = df.dropna(subset=['Rating', 'Reviews'])

# Create Review Length column (FIXED HERE)
df['Review_Length'] = df['Reviews'].astype(str).apply(len)

# Plot
plt.figure(figsize=(8,5))
sns.boxplot(x='Rating', y='Review_Length', data=df)

plt.title("Review Length vs Rating")
plt.xlabel("Rating")
plt.ylabel("Review Length")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The box plot was chosen to analyze the relationship between user ratings and review length because it effectively shows the distribution and variation of a numerical variable across different categories.
#
# In this case, the chart compares review length (numerical variable) with ratings (categorical variable from 1 to 5) in the dataset from the Google Play Store. A box plot is particularly useful because it displays key statistical measures such as median, quartiles, and outliers, providing a deeper understanding of how review lengths vary for each rating category.
#
# This visualization helps identify whether users with different satisfaction levels (ratings) behave differently in terms of how much feedback they provide. It is especially useful in detecting patterns, such as whether dissatisfied users tend to write longer and more detailed reviews compared to satisfied users.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the box plot showing the relationship between review length and ratings in the dataset from the Google Play Store, the following insights were observed:
#
# Lower ratings (1 and 2) tend to have longer reviews, indicating that dissatisfied users usually provide detailed feedback about the issues they face.
#
# Higher ratings (4 and 5) generally have shorter reviews, suggesting that satisfied users often give quick and brief responses.
#
# There is a higher variation in review length for low ratings, which shows that negative experiences lead to more expressive and detailed feedback.
#
# The presence of outliers (very long reviews) across ratings indicates that some users provide extensive feedback regardless of their satisfaction level.
#
# Key Insight
#
# Dissatisfied users are more likely to write detailed and lengthy reviews, while satisfied users tend to keep their feedback short and concise.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the review length vs rating analysis of the dataset from the Google Play Store can create a meaningful positive business impact.
#
# Since low-rated reviews are longer and more detailed, they provide valuable information about user problems such as bugs, performance issues, or poor user experience. Businesses can use this detailed feedback to identify and fix critical issues, leading to improved app quality and higher user satisfaction.
#
# By focusing on these detailed complaints, companies can make targeted improvements, which can increase ratings, enhance user retention, and boost app downloads.
#
# However, there are also insights that may lead to negative growth if ignored:
# The fact that dissatisfied users are writing long and detailed negative reviews indicates strong frustration. If these issues are not addressed, it can lead to negative word-of-mouth, poor app ratings, and reduced trust among potential users.
#
# Detailed negative reviews are highly visible to new users and can strongly influence their decision not to download the app, directly impacting growth and revenue.
#
# Conclusion
#
# These insights are highly valuable for business improvement, but only if acted upon. Addressing detailed user complaints can drive positive growth, while ignoring them can result in declining user trust and performance.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Count number of reviews per app
top_apps = df['App'].value_counts().head(10)

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=top_apps.values, y=top_apps.index)

plt.title("Top 10 Apps by Number of Reviews")
plt.xlabel("Number of Reviews")
plt.ylabel("App Name")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart was chosen to visualize the top 10 apps by number of reviews because it is the most effective way to compare categorical data (app names) with their corresponding numerical values (review counts).
# This chart makes it easy to identify which apps have received the highest number of reviews in the dataset from the Google Play Store. A bar chart provides clear visual comparison, allowing us to quickly spot the most popular and highly engaged apps.
# Additionally, focusing on the top 10 apps helps in simplifying the analysis and avoiding clutter, making the visualization more readable and insightful. It highlights the apps that generate the most user interaction, which is important for understanding user engagement and market popularity.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the bar chart showing the top 10 apps by number of reviews in the dataset from the Google Play Store, the following insights were observed:
# A few apps have a significantly higher number of reviews, indicating they are highly popular and widely used.
# The distribution is uneven, where only a small number of apps dominate user engagement, while others receive comparatively fewer reviews.
# Apps with more reviews tend to have higher user interaction, making them key focus areas for analysis and improvement.
# These top apps generate the majority of user feedback, which can provide valuable insights into user preferences and issues.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the top apps by number of reviews in the dataset from the Google Play Store can create a significant positive business impact.
# Apps with a high number of reviews indicate strong user engagement and popularity. Businesses can focus on these apps to better understand user preferences, improve features, and maintain their competitive advantage.
# High-engagement apps also provide a large volume of feedback, which can be used to make data-driven decisions and enhance user experience.
#
# These apps can be leveraged for marketing strategies, partnerships, and feature expansion to further increase growth.
#
# However, there are also insights that may lead to negative growth if not addressed:
#
# The fact that only a few apps dominate in terms of reviews shows an uneven distribution of user engagement. Less popular apps may struggle to gain visibility and user interaction.
# If popular apps receive a high number of reviews but also contain negative feedback, it can spread quickly due to their large user base, potentially harming brand reputation.
#
# Over-dependence on a few high-performing apps can be risky; if their performance declines, it may significantly impact overall business growth.
#
# Conclusion
#
# While the insights highlight strong opportunities for growth through high-engagement apps, businesses must also address feedback and ensure balanced development across all apps to avoid negative outcomes.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Get top 10 apps by number of reviews
top_apps = df['App'].value_counts().head(10).index

# Filter dataset for these apps
df_top = df[df['App'].isin(top_apps)]

# Calculate average rating per app
avg_rating = df_top.groupby('App')['Rating'].mean().sort_values()

# Plot
plt.figure(figsize=(10,6))
sns.barplot(x=avg_rating.values, y=avg_rating.index)

plt.title("Average Rating of Top 10 Apps")
plt.xlabel("Average Rating")
plt.ylabel("App Name")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is powerful because it combines two important aspects of app performance—popularity and user satisfaction—in a single visualization. By showing the average ratings of the most reviewed apps from the Google Play Store, it provides deeper insights than analyzing ratings or reviews separately.
# It helps identify apps that are not only widely used (high reviews) but also well-liked (high ratings), which are ideal for business success.
# It also highlights apps that are popular but have lower average ratings, indicating potential issues despite high usage.
# This comparison enables better decision-making by distinguishing between high engagement and actual user satisfaction.
# The chart simplifies complex data into an easy-to-understand format, making it easier to spot performance gaps among top apps.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart showing the average rating of the top reviewed apps in the dataset from the Google Play Store, the following insights were observed:
# Some apps have both high review counts and high average ratings, indicating strong user satisfaction along with high popularity.
#
# A few highly reviewed apps show lower average ratings, suggesting that popularity does not always guarantee a positive user experience.
#
# Apps with lower average ratings may be receiving many downloads, but users could be facing issues related to performance, usability, or reliability.
# The chart helps distinguish between apps that are simply popular and apps that are truly delivering a good experience to users.
#
# Key Insight
#
# The analysis shows that some apps successfully maintain both popularity and user satisfaction, while others attract many users but still need improvement in overall experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this analysis of average ratings for top-reviewed apps in the Google Play Store can strongly support positive business impact.
#
# Apps that maintain both high engagement (many reviews) and high average ratings indicate strong user satisfaction and product quality.
#
# These can act as benchmarks for feature design, performance standards, and user experience improvements.
# Businesses can use these insights to prioritize what works, enhance successful features, and improve customer retention and app rankings.
#
# Understanding the gap between popularity and satisfaction helps in making data-driven decisions that directly improve user experience and growth.
#
# However, there are also insights that may lead to negative growth if not addressed:
#
# Apps that are highly popular but show lower average ratings indicate that users are facing issues despite widespread usage.
#
# If these problems (such as bugs, crashes, or poor usability) are ignored, it can lead to negative reviews, reduced user trust, higher uninstall rates, and lower future downloads.
#
# Over time, dissatisfied users may switch to competitors, leading to loss of market share and revenue decline.
#
# Conclusion
#
# The insights are highly valuable for driving growth, but only if acted upon. Improving user satisfaction alongside maintaining popularity is key to long-term business success.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Check if Category exists
df.columns

# Plot
plt.figure(figsize=(12,6))
sns.boxplot(x='Category', y='Rating', data=df)

plt.title("Rating Distribution Across App Categories")
plt.xlabel("App Category")
plt.ylabel("Rating")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is useful because it helps compare how user ratings vary across different app categories in the Google Play Store. It provides a clear view of which categories perform well and which may need improvement.
#
# It allows easy comparison of user satisfaction across categories, helping identify high-performing and low-performing segments.
#
# The box plot shows distribution, median, and variation, giving deeper insights into consistency of ratings within each category.
#
# It helps detect outliers, which may indicate unusually good or poor-performing apps in a category.
# Businesses can use this information to understand market trends and user expectations in different categories.
#
# Key Value
#
# This chart helps in identifying which app categories deliver better user experience and which ones require attention for improvement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the box plot showing rating distribution across app categories in the dataset from the Google Play Store, the following insights were observed:
#
# Some categories consistently show higher median ratings, indicating better user satisfaction in those segments.
#
# Certain categories have lower median ratings and wider spread, suggesting inconsistent performance and mixed user experiences.
#
# The presence of outliers indicates that within each category, some apps perform exceptionally well or poorly compared to others.
#
# Categories with a narrow spread of ratings indicate more stable and consistent user experience, while wider spread reflects variability in app quality.
#
# Key Insight
#
# User satisfaction varies significantly across different app categories, with some categories consistently performing better while others show mixed or inconsistent feedback.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the rating distribution across categories in the Google Play Store can create a meaningful positive business impact.
#
# Categories with consistently high ratings indicate strong user satisfaction. Businesses can study these categories to understand what features, design, or performance standards are working well and apply similar strategies to other apps.
#
# It helps organizations identify high-performing segments where they can invest more resources, expand offerings, and maximize growth opportunities.
#
# Categories with stable ratings reflect consistent user experience, which is essential for building trust and long-term user retention.
#
# However, there are also insights that may lead to negative growth if ignored:
# Categories showing lower median ratings and high variability indicate inconsistent app quality and user dissatisfaction.
#
# If these issues (such as poor performance, bugs, or usability problems) are not addressed, it can lead to negative reviews, reduced downloads, and lower user retention.
# High variability also suggests lack of standard quality across apps, which can weaken overall brand trust in that category.
#
# Conclusion
# These insights help businesses identify both strengths and weaknesses across categories. Focusing on improving low-performing categories while maintaining high-performing ones is key to sustainable growth.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Select only numeric columns
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Plot heatmap
plt.figure(figsize=(8,6))
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap="coolwarm")

plt.title("Correlation Heatmap of Numerical Features")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation heatmap was chosen to understand the relationships between numerical variables in the dataset from the Google Play Store.
#
# It provides a visual representation of correlation values, making it easy to identify how strongly variables are related to each other.
#
# The heatmap uses color intensity to highlight positive, negative, or no correlation, which simplifies interpretation compared to raw numbers.
# It helps in detecting patterns and dependencies between variables such as rating and review-related features.
#
# This chart is especially useful for identifying whether changes in one variable are associated with changes in another.
#
# Key Value
#
# The heatmap helps quickly identify relationships between variables, which is important for understanding data patterns and making informed decisions during analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the correlation heatmap of numerical features in the dataset from the Google Play Store, the following insights were observed:
#
# Most variables show weak or low correlation, indicating that they are largely independent of each other.
#
# The Rating variable does not have a strong correlation with other numerical features (such as review length, if included), suggesting that user ratings are influenced by multiple factors rather than a single measurable variable.
#
# If a slight negative or positive correlation exists (e.g., between rating and review length), it indicates a minor relationship, but not strong enough to draw direct conclusions.
#
# The absence of strong correlations suggests that user behavior is complex and multi-dimensional, and cannot be explained by a single factor.
#
# Key Insight
#
# There is no strong linear relationship between numerical variables, indicating that user ratings and behavior depend on multiple independent factors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the correlation heatmap of the dataset from the Google Play Store can support positive business impact.
#
# The finding that most variables have weak correlations indicates that user ratings are influenced by multiple independent factors rather than a single metric. This encourages businesses to take a holistic approach—improving performance, usability, features, and overall user experience instead of focusing on just one area.
#
# It helps decision-makers avoid oversimplified assumptions, leading to more accurate and data-driven strategies for improving app quality and user satisfaction.
#
# However, there are also insights that may lead to negative growth if misunderstood or ignored:
#
# Since no single factor strongly influences ratings, focusing improvement efforts on just one aspect (e.g., only increasing features but ignoring performance) may not significantly improve user satisfaction.
#
# Misinterpreting weak correlations as “no problem” could lead to neglecting important user issues, resulting in continued dissatisfaction, negative reviews, and reduced retention.
# Lack of clear relationships may make it harder to identify priority areas, and without proper analysis, this can lead to inefficient decision-making and wasted resources.
#
# Conclusion
#
# These insights highlight the need for a comprehensive improvement strategy. Addressing multiple aspects of the app simultaneously is essential for sustainable growth.Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# Group data by App
app_data = df.groupby('App').agg({
    'Reviews': 'count',
        'Rating': 'mean'
        }).reset_index()

        # Rename columns for clarity
app_data.columns = ['App', 'Review_Count', 'Avg_Rating']

        # Plot scatter plot
plt.figure(figsize=(8,6))
sns.scatterplot(x='Review_Count', y='Avg_Rating', data=app_data)

plt.title("Number of Reviews vs Average Rating")
plt.xlabel("Number of Reviews")
plt.ylabel("Average Rating")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This scatter plot is powerful because it brings together two critical aspects of app performance—user engagement (number of reviews) and user satisfaction (average rating)—in a single view.
#
# Using data from the Google Play Store, this chart allows us to:
#
# Identify top-performing apps that have both high review counts and high ratings, indicating strong popularity and user satisfaction.
#
# Detect problem areas, such as apps with high reviews but low ratings, which suggests many users are experiencing issues.
#
# Understand whether there is any relationship between engagement and satisfaction, helping in deeper analysis of user behavior.
#
# Visually segment apps into groups (high-high, high-low, low-high), making it easier for businesses to prioritize actions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the scatter plot showing the relationship between number of reviews and average rating in the dataset from the Google Play Store, the following insights were observed:
#
# Apps with high review counts and high ratings represent top-performing apps, indicating both strong popularity and high user satisfaction.
#
# Some apps have high review counts but lower average ratings, suggesting that while they are widely used, users may be facing issues or dissatisfaction.
# Apps with low review counts but high ratings may be niche or new apps that have good quality but lower visibility.
#
# There is no strong linear relationship between number of reviews and ratings, indicating that higher engagement does not always guarantee better user satisfaction.
#
# Key Insights
#
# Popularity and user satisfaction do not always go hand in hand—some highly used apps may still have lower ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from the relationship between number of reviews and average rating in the dataset from the Google Play Store can create a strong positive business impact.
#
# Apps that show high review counts along with high ratings indicate both strong popularity and user satisfaction. These apps can be used as benchmarks to understand successful strategies, helping businesses improve product quality and user experience.
# Identifying apps with high ratings but low review counts can help businesses focus on marketing and visibility, as these apps have potential for growth but are currently underexposed.
# This analysis supports data-driven decision-making, allowing companies to balance both engagement and quality for better outcomes.
#
# However, there are also insights that may lead to negative growth if not addressed:
#
# Apps with high review counts but low average ratings indicate widespread usage but poor user satisfaction. If these issues are ignored, it can lead to negative reviews, poor ratings, reduced user trust, and higher uninstall rates.
#
# Since these apps already have a large user base, negative feedback can spread quickly and significantly impact brand reputation and future growth.
#
# The lack of a strong relationship between reviews and ratings suggests that simply increasing user engagement without improving quality may not lead to better outcomes.
#
# Conclusion
#
# These insights highlight the importance of balancing user engagement with user satisfaction. Focusing on both aspects is essential for sustainable business growth.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# Plot
plt.figure(figsize=(8,5))
sns.countplot(x='Rating', data=df)

plt.title("Number of Reviews per Rating")
plt.xlabel("Rating")
plt.ylabel("Number of Reviews")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
